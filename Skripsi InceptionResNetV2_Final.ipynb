# %% [markdown]
# ## The InceptionResNetV2 model development and fine tuning
#
# in this notebook we will load and add our layers to the base model of the pre-trained InceptionResNetV2 model, and fine tune the following parameters of the model:
#
# # **Setting up the Environment**

# %%
# Delete All Folder
# import shutil
# shutil.rmtree('/content/Brain Tumor Dataset')
# shutil.rmtree('/content/Brain Tumor Dataset-cropped')
# shutil.rmtree('/content/Brain Tumor Dataset-proccess')
# shutil.rmtree('/content/dataset-testing')
# shutil.rmtree('/content/dataset-testing-cropped')
# shutil.rmtree('/content/dataset-testing-proccess')
# shutil.rmtree('/content/preview')

# %%
import pandas as pd
import numpy as np
import os
import tensorflow as tf
import keras
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from keras.applications.inception_resnet_v2 import InceptionResNetV2
from tensorflow.keras.preprocessing import image
# from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input
from sklearn.metrics import confusion_matrix
from tensorflow.keras.applications import InceptionResNetV2
from tqdm import tqdm_notebook
import time
# import tqdm.gui as tqdm
# import tqdm.notebook as tqdm
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report
from tqdm import tqdm
import pickle

import glob
import random
from matplotlib.image import imread
import cv2
import imutils
from pathlib import Path
from tensorflow.keras.applications.inception_resnet_v2 import preprocess_input as preprocess_input_inceptionresnetv2
from keras.metrics import Precision, Recall, AUC
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import seaborn as sns

from tensorflow.keras.layers import Activation, Dense
from tabulate import tabulate
from sklearn.model_selection import StratifiedKFold
from pylab import rcParams

# %%
#Menghubungkan ke google drive

from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# Mengambil dataset dari google drive

import zipfile  # library untuk mempercepat extract file
dataset_path = "/gdrive/My Drive/SKRIPSI/Dataset/Brain Tumor Dataset.zip"
# dataset_path = "/gdrive/My Drive/SKRIPSI/Dataset/dataset-testing.zip"
zfile = zipfile.ZipFile(dataset_path)
zfile.extractall()

# %%
# Konstanta
IMG_PATH = '/content/Brain Tumor Dataset/'
# IMG_PATH= '/content/dataset-testing'
CROPPED_IMG_PATH = '/content/Brain Tumor Dataset-cropped'
# CROPPED_IMG_PATH = '/content/dataset-testing-cropped'
PROCCESS_IMG_PATH = '/content/Brain Tumor Dataset-proccess'
# PROCCESS_IMG_PATH = '/content/dataset-testing-proccess'
RESULT_FOLDER = '/gdrive/My Drive/SKRIPSI/Result/InceptionResNetV2_Coba3/'
IMG_SIZE = 300, 300

# %% [markdown]
# # **Common functions**

# %%
# common functions that i will use

def get_data_generator(train_data_path, \
                       val_data_path, \
                       targetsize, \
                       classmode, \
                       batchsize):
    """
    This function is a data generator function for train, validation, and testing data
    Inputs
        train_data_path   : train data path for the dataset 
        val_data_path     : validation data path for the dataset
        targetsize        : target size for the generator to resize all images to, (224,224)
        classmode         : class mode, 'categorical'
        batchsize         : batch size
    Outputs
        train_generator   : generated train data
        val_generator     : generated validation data
    
    """
    train_datagen=ImageDataGenerator(preprocessing_function=preprocess_input)
    val_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
    
    
    train_generator=train_datagen.flow_from_directory(train_data_path, # this is where you specify the path to the main data folder
                                                 target_size=targetsize,
                                                 color_mode='rgb',
                                                 batch_size=batchsize,
                                                 class_mode=classmode,
                                                 shuffle=True)
    
    val_generator=val_datagen.flow_from_directory(val_data_path, # this is where you specify the path to the main data folder
                                                 target_size=targetsize,
                                                 color_mode='rgb',
                                                 batch_size=batchsize,
                                                 class_mode=classmode)
 
    return train_generator,val_generator

# %%
def train_evaluate_the_model(train_generator, val_generator, optimizer, epochs, dropout_value, TheModel):
    '''
    train the model, do predictions, and do evaluation and return the accuracy, precision, recall, and f1-score of the model
    Inputs
        train_generator : generated train data
        val_generator   : generated validation data
        optimizer       : the optimizer method used to compile the model
        epochs          : the epochs of the model use to fit the model
        dropout_value   : the dropout value
        TheModel        : The pretrained model loaded,
    Outputs
        accuracy        : The accuracy of the model
        precision       : The precision of the model
        recall          : The recall of the model
        f1_score        : The f1_score of the model
    '''

    # freeze base layers for training
    for layer in TheModel.layers:
        layer.trainable = False

    # load pretrained model and add layers on top of the model
    x = TheModel.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(512, activation='relu', kernel_regularizer=l1_l2(l1=1e-5, l2=1e-4))(x)
    x = BatchNormalization()(x)
    x = tf.keras.layers.Dropout(dropout_value)(x)
    x = Dense(256, activation='relu', kernel_regularizer=l1_l2(l1=1e-5, l2=1e-4))(x)
    x = BatchNormalization()(x)
    x = tf.keras.layers.Dropout(dropout_value)(x)
    predictions = Dense(4, activation="softmax")(x)
    model = Model(inputs = TheModel.input, outputs = predictions)

    # compile the model
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

    # fit the model

    tic = time.time()
    # Train model 
    step_size_train = train_generator.n//train_generator.batch_size
    r = model.fit(train_generator,
                            validation_data=val_generator,
                            steps_per_epoch=step_size_train,
                            epochs=epochs,callbacks=[early_stop])
    toc = time.time()

    predictions = model.predict(val_generator)
    y_true = val_generator.labels
    y_pred = np.argmax(predictions, axis=1)

     # hitung confusion matrix dan hasil evaluasi per kelas
    cm = confusion_matrix(y_true, y_pred)
    class_names = train_generator.class_indices.keys()
    report = classification_report(y_true, y_pred, target_names=class_names, output_dict=True)

     # hitung specificity 
    tn, fp, fn, tp = cm[0][0], cm[0][1], cm[1][0], cm[1][1]
    specificity = []
    for i in range(len(class_names)):
        spec = tn / (tn + fp)
        specificity.append(spec)
    
    # tampilkan confusion matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.title(f'Confusion Matrix')
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.show()

    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='macro')
    sensitivity_ava = recall_score(y_true, y_pred, average='macro')
    f1 = f1_score(y_true, y_pred, average='macro')
    time_taken = toc - tic

    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']

    loss = history.history['loss']
    val_loss = history.history['val_loss']

    plt.figure(figsize=(8, 8))
    plt.subplot(2, 1, 1)
    plt.plot(acc, label='Training Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.ylabel('Accuracy')
    plt.ylim([min(plt.ylim()),1])
    plt.title(f'Training and Validation Accuracy InceptionResNetV2')

    plt.subplot(2, 1, 2)
    plt.plot(loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.ylabel('Cross Entropy')
    plt.ylim([0,1.0])
    plt.title(f'Training and Validation Loss InceptionResNetV2')
    plt.xlabel('epoch')
    plt.show()

    return accuracy, precision, sensitivity_ava,np.mean(specificity), f1, time_taken/60.0, model

# %%
def crop_imgs(set_name, add_pixels_value=0):
    """
    Finds the extreme points on the image and crops the rectangular out of them
    """
    set_new = []
    for img in set_name:
        gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
        gray = cv2.GaussianBlur(gray, (5, 5), 0)

        # threshold the image, then perform a series of erosions +
        # dilations to remove any small regions of noise
        thresh = cv2.threshold(gray, 45, 255, cv2.THRESH_BINARY)[1]
        thresh = cv2.erode(thresh, None, iterations=2)
        thresh = cv2.dilate(thresh, None, iterations=2)

        # find contours in thresholded image, then grab the largest one
        cnts = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        cnts = imutils.grab_contours(cnts)
        c = max(cnts, key=cv2.contourArea)

        # find the extreme points
        extLeft = tuple(c[c[:, :, 0].argmin()][0])
        extRight = tuple(c[c[:, :, 0].argmax()][0])
        extTop = tuple(c[c[:, :, 1].argmin()][0])
        extBot = tuple(c[c[:, :, 1].argmax()][0])

        ADD_PIXELS = add_pixels_value
        new_img = img[extTop[1]-ADD_PIXELS:extBot[1]+ADD_PIXELS, extLeft[0]-ADD_PIXELS:extRight[0]+ADD_PIXELS].copy()
        set_new.append(new_img)

    return np.array(set_new)

# %%
def create_folder(folder_path):
    """
    Create a new folder at the specified path.
    :param folder_path: Path to the new folder
    :type folder_path: str
    """
    try:
        os.mkdir(folder_path)
        print(f"Folder '{folder_path}' created successfully.")
    except FileExistsError:
        print(f"Folder '{folder_path}' already exists.")

# %%
def plot_sample(class_names, img_dir, num_samples=10):
    """
    Plot sample images from each label in class_names
    :param class_names: List of class names
    :param img_dir: Path to directory containing image files
    :param num_samples: Number of images to plot per label
    """
    # create dictionary of class indices
    class_indices = {class_names[i]: i for i in range(len(class_names))}

    # create subplot for each class
    fig, axes = plt.subplots(nrows=len(class_names), ncols=num_samples, figsize=(12, 12))

    # plot each image for each class
    for i, label in enumerate(class_names):
        # path to directory for current label
        label_dir = os.path.join(img_dir, label)
        # list of file names in current directory
        file_names = os.listdir(label_dir)
        # select random samples from list
        samples = random.sample(file_names, num_samples)
        for j, sample in enumerate(samples):
            # path to current image file
            img_path = os.path.join(label_dir, sample)
            # read image file
            img = imread(img_path)
            # plot image
            axes[i, j].imshow(img)
            axes[i, j].axis("off")
            if j == num_samples // 2:
                axes[i, j].set_title(label, y=1.2)
    plt.show()

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure(figsize = (6,6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    cm = np.round(cm,2)
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# %%
def apply_crop(IMG_PATH_BEFORE,IMG_PATH_AFTER): 
  before = os.listdir(IMG_PATH_BEFORE)
  after = os.listdir(IMG_PATH_AFTER)

  # apply this for each set
  for folder in before:
      folder_path = os.path.join(IMG_PATH_BEFORE, folder)
      if os.path.isdir(folder_path):
          output_folder_path = os.path.join(IMG_PATH_AFTER, folder)
          Path(output_folder_path).mkdir(parents=True, exist_ok=True) # create the output folder if it does not exist
          for file_name in os.listdir(folder_path):
              if file_name.endswith(".jpg"): # assuming that the images are in JPG format
                  file_path = os.path.join(folder_path, file_name)
                  img = cv2.imread(file_path)
                  cropped_imgs = crop_imgs([img])
                  for i, cropped_img in enumerate(cropped_imgs):
                      output_file_path = os.path.join(output_folder_path, f"{file_name[:-4]}_cropped_{i}.jpg") # assuming that you want to append _cropped_0, _cropped_1, etc. to the original file name
                      cv2.imwrite(output_file_path, cropped_img)

# %%
from tensorflow.keras.applications.inception_resnet_v2 import preprocess_input

def apply_preprocessing(IMG_PATH_BEFORE, IMG_PATH_AFTER, img_size=(299,299)):
    """
    Resize and apply inceptionresnetv2 preprocessing and save the images to output_dir
    """
    # create output_dir if it does not exist
    os.makedirs(IMG_PATH_AFTER, exist_ok=True)
    
    for class_name in os.listdir(IMG_PATH_BEFORE):
        class_dir = os.path.join(IMG_PATH_BEFORE, class_name)
        for img_path in os.listdir(class_dir):
            img_path = os.path.join(class_dir, img_path)
            # Load image from file path
            img = cv2.imread(img_path)
            # Resize image
            img = cv2.resize(
                img,
                dsize=img_size,
                interpolation=cv2.INTER_CUBIC
            )
            # Save the preprocessed image
            output_path = os.path.join(IMG_PATH_AFTER, class_name, os.path.basename(img_path))
            os.makedirs(os.path.dirname(output_path), exist_ok=True)
            cv2.imwrite(output_path, img)

# %%
def plot_results(x_axis, x_label,y_axis, y_label):
    rcParams['figure.figsize'] = 10,8 # width 10, height 8
    ax = result_table.plot(x=x_axis, y=y_axis, style='bx-', grid=True)
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)

# %%
def upload_drive(FILE_PATH,TARGET_FOLDER):
  # path file yang akan diupload
  file_path = '/content/'+FILE_PATH

  # folder tujuan di Google Drive
  target_folder = TARGET_FOLDER

  # nama file setelah diupload
  file_name = os.path.basename(file_path)

  # copy file ke Google Drive
  # !cp "{file_path}" "{target_folder}/{file_name}"
  print(f'File {file_name} berhasil diupload ke folder {target_folder}')

# %%
def create_optimizer(optimizer, learning_rate=1e-4):
    if optimizer == 'Adam':
        return tf.keras.optimizers.Adam(learning_rate=learning_rate)
    elif optimizer == 'Adamax':
        return tf.keras.optimizers.Adamax(learning_rate=learning_rate)
    elif optimizer == 'Nadam':
        return tf.keras.optimizers.Nadam(learning_rate=learning_rate)
    else:
        raise ValueError('Invalid optimizer :',optimizer)

# %%
from tensorflow.keras.callbacks import EarlyStopping

# Create an early stopping callback
early_stop = EarlyStopping(monitor='val_loss', patience=5)

# %% [markdown]
# # **Data import and Preprocessing**

# %%
# Ambil nama folder yang berisi data
label = os.listdir(IMG_PATH)

# %%
class_indices = {label[i]: i for i in range(len(label))}

print("Label Class : ",class_indices," \n")

# Loop melalui setiap folder dan ambil nama file
sum = 0
for label_name in label:
    file_names = glob.glob(os.path.join(IMG_PATH, label_name, '*'))
    num_files = len(file_names)
    sum += num_files
    print(f'{label_name}: {num_files} images')
print()
print("Total: ", sum, " images")
# Out:
# Label Class :  {'pituitary': 0, 'meningioma': 1, 'notumor': 2, 'glioma': 3}
#
# pituitary: 1757 images
# meningioma: 1645 images
# notumor: 2000 images
# glioma: 1621 images
#
# Total:  7023  images

# %%
plot_sample(label,IMG_PATH,10)

# %% [markdown]
# **CROPPING IMAGES**

# %%
img = cv2.imread('/content/Brain Tumor Dataset/glioma/Te-glTr_0000.jpg')
# img = cv2.imread('/content/dataset-testing/glioma_tumor/image(1).jpg')
img = cv2.resize(
            img,
            dsize=IMG_SIZE,
            interpolation=cv2.INTER_CUBIC
        )
gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
gray = cv2.GaussianBlur(gray, (5, 5), 0)

# threshold the image, then perform a series of erosions +
# dilations to remove any small regions of noise
thresh = cv2.threshold(gray, 45, 255, cv2.THRESH_BINARY)[1]
thresh = cv2.erode(thresh, None, iterations=2)
thresh = cv2.dilate(thresh, None, iterations=2)

# find contours in thresholded image, then grab the largest one
cnts = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
cnts = imutils.grab_contours(cnts)
c = max(cnts, key=cv2.contourArea)

# find the extreme points
extLeft = tuple(c[c[:, :, 0].argmin()][0])
extRight = tuple(c[c[:, :, 0].argmax()][0])
extTop = tuple(c[c[:, :, 1].argmin()][0])
extBot = tuple(c[c[:, :, 1].argmax()][0])

# add contour on the image
img_cnt = cv2.drawContours(img.copy(), [c], -1, (0, 255, 255), 4)

# add extreme points
img_pnt = cv2.circle(img_cnt.copy(), extLeft, 8, (0, 0, 255), -1)
img_pnt = cv2.circle(img_pnt, extRight, 8, (0, 255, 0), -1)
img_pnt = cv2.circle(img_pnt, extTop, 8, (255, 0, 0), -1)
img_pnt = cv2.circle(img_pnt, extBot, 8, (255, 255, 0), -1)

# crop
ADD_PIXELS = 0
new_img = img[extTop[1]-ADD_PIXELS:extBot[1]+ADD_PIXELS, extLeft[0]-ADD_PIXELS:extRight[0]+ADD_PIXELS].copy()

# %%
plt.figure(figsize=(15,6))
plt.subplot(141)
plt.imshow(img)
plt.xticks([])
plt.yticks([])
plt.title('Step 1. Get the original image')
plt.subplot(142)
plt.imshow(img_cnt)
plt.xticks([])
plt.yticks([])
plt.title('Step 2. Find the biggest contour')
plt.subplot(143)
plt.imshow(img_pnt)
plt.xticks([])
plt.yticks([])
plt.title('Step 3. Find the extreme points')
plt.subplot(144)
plt.imshow(new_img)
plt.xticks([])
plt.yticks([])
plt.title('Step 4. Crop the image')
plt.show()

# %%
create_folder(CROPPED_IMG_PATH)
# Out:
# Folder '/content/Brain Tumor Dataset-cropped' created successfully.

# %%
apply_crop(IMG_PATH,CROPPED_IMG_PATH)

# %%
plot_sample(label,CROPPED_IMG_PATH,10)

# %%
create_folder(PROCCESS_IMG_PATH)
# Out:
# Folder '/content/Brain Tumor Dataset-proccess' created successfully.

# %%
apply_preprocessing(CROPPED_IMG_PATH,PROCCESS_IMG_PATH,IMG_SIZE)

# %%
plot_sample(label,PROCCESS_IMG_PATH,10)

# %% [markdown]
# **Augmentasi Data**

# %%
demo_datagen = ImageDataGenerator(
    rescale=1./255, 
    rotation_range=20, 
    shear_range=0.2, 
    zoom_range=0.2, 
    horizontal_flip=True, 
    vertical_flip=True, 
    fill_mode='nearest')

# %%
os.mkdir('preview')
x = cv2.imread('/content/Brain Tumor Dataset-proccess/glioma/Te-glTr_0000_cropped_0.jpg')  
# x = cv2.imread('/content/dataset-testing/glioma_tumor/image(1).jpg')  
x = np.expand_dims(x, axis=0)

i = 0
for batch in demo_datagen.flow(x, batch_size=1, save_to_dir='preview', save_prefix='aug_img', save_format='jpg'):
    i += 1
    if i > 20:
        break

# %%
plt.imshow(cv2.imread('/content/Brain Tumor Dataset-proccess/glioma/Te-glTr_0000_cropped_0.jpg')  )
# plt.imshow(cv2.imread('/content/dataset-testing/glioma_tumor/image(1).jpg')  )

plt.xticks([])
plt.yticks([])
plt.title('Original Image')
plt.show()

plt.figure(figsize=(15,6))
i = 1
for img in os.listdir('preview/'):
    img = cv2.imread('preview/' + img)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.subplot(3,7,i)
    plt.imshow(img)
    plt.xticks([])
    plt.yticks([])
    i += 1
    if i > 3*7:
        break
plt.suptitle('Augemented Images')
plt.show()

# %%
# !rm -rf preview/

# %% [markdown]
# # **Train Initial**

# %%
# initial parameters
batchsize_initial = 64
epochs_initial = 50
dropout_value_initial = 0.2
optimizer_initial = 'Adam'
num_folds = 5


# tetsing
# batchsize_initial = 1
# epochs_initial = 1
# dropout_value_initial = 0.0
# optimizer_initial = 'Adam'
# num_folds = 2 


# constant parameters
targetsize_constant = (IMG_SIZE)
classmode_constant = 'categorical'

# %%
# Buat list path gambar dan label pada dataset
image_paths = []
image_labels = []
for label_dir in os.listdir(PROCCESS_IMG_PATH):
    label = label_dir.lower()
    label_path = os.path.join(PROCCESS_IMG_PATH, label_dir)
    for image_file in os.listdir(label_path):
        image_path = os.path.join(label_path, image_file)
        image_paths.append(image_path)
        image_labels.append(label)

# Buat dataframe berisi path gambar dan label
df = pd.DataFrame({'path': image_paths, 'label': image_labels})

# Ubah tipe data kolom "label" menjadi string
df['label'] = df['label'].astype(str)

# Buat data generator
datagen = ImageDataGenerator(
    rescale=1./255, 
    rotation_range=20, 
    shear_range=0.2, 
    zoom_range=0.2, 
    horizontal_flip=True, 
    vertical_flip=True, 
    fill_mode='nearest')

# Lakukan cross validation
skf = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
from tensorflow.keras.regularizers import l1_l2

# %%
results = []
results_class = []
best_sensitivity = 0
best_fold = 0

for fold, (train_index, val_index) in enumerate(skf.split(df['path'], df['label'])):
    train_df = df.iloc[train_index]
    val_df = df.iloc[val_index]

    # simpan train_df dan val_df di setiap foldnya
    with open(f'train_df_fold{fold+1}.pkl', 'wb') as f:
        pickle.dump(train_df, f)
    with open(f'val_df_fold{fold+1}.pkl', 'wb') as f:
        pickle.dump(val_df, f)

    upload_drive(f'train_df_fold{fold+1}.pkl',RESULT_FOLDER)
    upload_drive(f'val_df_fold{fold+1}.pkl',RESULT_FOLDER)


    image_size = [299,299] # choose image size

    train_generator_initial = datagen.flow_from_dataframe(dataframe=train_df,
                                                           x_col='path',
                                                           y_col='label',
                                                           color_mode='rgb',
                                                           batch_size=batchsize_initial,
                                                           class_mode="categorical",
                                                           shuffle=True)
    val_generator_initial = datagen.flow_from_dataframe(dataframe=val_df,
                                                         x_col='path',
                                                         y_col='label',
                                                         color_mode='rgb',
                                                         batch_size=batchsize_initial,
                                                         class_mode="categorical",
                                                         shuffle=True)

    # import the base model
    inceptionresnetv2_basemodel = tf.keras.applications.InceptionResNetV2(input_shape= image_size+[3],weights='imagenet',include_top=False)

    # storing the base model in the kernel for later use to avoid loading many times
    base_model = inceptionresnetv2_basemodel

    # Freeze layer pada model
    for layer in base_model.layers:
        layer.trainable = False

    # Tambahkan layer klasifikasi pada model
    # add layers
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(512, activation='relu', kernel_regularizer=l1_l2(l1=1e-5, l2=1e-4))(x)
    x = BatchNormalization()(x)
    x = tf.keras.layers.Dropout(dropout_value_initial)(x)
    x = Dense(256, activation='relu', kernel_regularizer=l1_l2(l1=1e-5, l2=1e-4))(x)
    x = BatchNormalization()(x)
    x = tf.keras.layers.Dropout(dropout_value_initial)(x)
    predictions = Dense(4, activation="softmax")(x)
    model = Model(inputs = base_model.input, outputs = predictions)

    optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)
    # compile the model
    model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

    tic = time.time()
    # Train model pada setiap fold
    step_size_train_initial=train_generator_initial.n//train_generator_initial.batch_size
    history = model.fit(train_generator_initial, epochs=epochs_initial,steps_per_epoch=step_size_train_initial, validation_data=val_generator_initial,callbacks=[early_stop])

    toc = time.time()

    # Evaluasi model pada validasi set
    val_generator = datagen.flow_from_dataframe(dataframe=val_df,
                                                x_col='path',
                                                y_col='label',
                                                color_mode='rgb',
                                                batch_size=batchsize_initial,
                                                class_mode="categorical",
                                                shuffle=False)
    scores = model.evaluate(val_generator)
    print("%s%s: %.2f%%" % ("evaluate ",model.metrics_names[1], scores[1]*100))

    predictions = model.predict(val_generator)
    y_true = val_generator.labels
    y_pred = np.argmax(predictions, axis=1)

    # hitung confusion matrix dan hasil evaluasi per kelas
    cm = confusion_matrix(y_true, y_pred)
    class_names = train_generator_initial.class_indices.keys()
    report = classification_report(y_true, y_pred, target_names=class_names, output_dict=True)

     # hitung specificity 
    tn, fp, fn, tp = cm[0][0], cm[0][1], cm[1][0], cm[1][1]
    specificity = []
    for i in range(len(class_names)):
        spec = tn / (tn + fp)
        specificity.append(spec)

    # tampilkan confusion matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.title(f'Confusion Matrix (Fold {fold+1})')
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.show()

    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='macro')
    sensitivity_ava = recall_score(y_true, y_pred, average='macro')
    f1 = f1_score(y_true, y_pred, average='macro')
    time_taken = toc - tic

    if fold == 0:
      best_sensitivity = sensitivity_ava
      best_fold = fold+1
    elif best_sensitivity < sensitivity_ava:
      best_sensitivity = sensitivity_ava
      best_fold = fold+1

    # tampilkan hasil evaluasi per kelas
    for i, name in enumerate(class_names):
        results_class.append({'fold': fold+1, 'class': name,'accuracy': accuracy,'precision': report[name]['precision'],
                                  'sensitivity': report[name]['recall'], 'specificity': specificity[i],
                                   'f1-score': report[name]['f1-score'], 'time_taken': time_taken/60.0})

    results.append({'fold':fold+1,
                'accuracy': accuracy,
                'precision': precision,
                'sensitivity': sensitivity_ava,
                'specificity': np.mean(specificity),
                'f1-score': f1,
                'time_taken': time_taken/60.0})

    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']

    loss = history.history['loss']
    val_loss = history.history['val_loss']

    plt.figure(figsize=(8, 8))
    plt.subplot(2, 1, 1)
    plt.plot(acc, label='Training Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.ylabel('Accuracy')
    plt.ylim([min(plt.ylim()),1])
    plt.title(f'Training and Validation Accuracy InceptionResNetV2 (Fold {fold+1})')

    plt.subplot(2, 1, 2)
    plt.plot(loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.ylabel('Cross Entropy')
    plt.ylim([0,1.0])
    plt.title(f'Training and Validation Loss InceptionResNetV2 (Fold {fold+1})')
    plt.xlabel('epoch')
    plt.show()
    

    model.save(f'fold_{fold+1}_model.h5')
    upload_drive(f'fold_{fold+1}_model.h5',RESULT_FOLDER)

# Konversi list results ke dalam dataframe pandas
df_results = pd.DataFrame(results, columns=['fold', 'accuracy','precision', 'sensitivity','specificity', 'f1-score', 'time_taken'])
df_results_class = pd.DataFrame(results_class, columns=['fold', 'class','accuracy', 'precision','sensitivity', 'specificity', 'f1-score', 'time_taken'])
# Tampilkan hasil evaluasi dalam bentuk tabel
pd.DataFrame(df_results)
pd.DataFrame(df_results_class)
print('Best Fold:',best_fold)
print('Best Sensitivity:',best_sensitivity)
# Out:
# File train_df_fold1.pkl berhasil diupload ke folder /gdrive/My Drive/SKRIPSI/Result/InceptionResNetV2_Coba3/
# File val_df_fold1.pkl berhasil diupload ke folder /gdrive/My Drive/SKRIPSI/Result/InceptionResNetV2_Coba3/
# Found 5618 validated image filenames belonging to 4 classes.
# Found 1405 validated image filenames belonging to 4 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_resnet_v2/inception_resnet_v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 219055592/219055592 [==============================] - 7s 0us/step
# Epoch 1/50
# 87/87 [==============================] - 153s 1s/step - loss: 1.2764 - accuracy: 0.6748 - val_loss: 1.0663 - val_accuracy: 0.7445
# Epoch 2/50
# 87/87 [==============================] - 106s 1s/step - loss: 0.9466 - accuracy: 0.7901 - val_loss: 0.8608 - val_accuracy: 0.8221
# Epoch 3/50
# 87/87 [==============================] - 108s 1s/step - loss: 0.8771 - accuracy: 0.8180 - val_loss: 0.8015 - val_accuracy: 0.8555
# Epoch 4/50
# 87/87 [==============================] - 108s 1s/step - loss: 0.8114 - accuracy: 0.8401 - val_loss: 0.7472 - val_accuracy: 0.8705
# Epoch 5/50
# 87/87 [==============================] - 106s 1s/step - loss: 0.8001 - accuracy: 0.8425 - val_loss: 0.7399 - val_accuracy: 0.8655
# Epoch 6/50
# 87/87 [==============================] - 108s 1s/step - loss: 0.7687 - accuracy: 0.8533 - val_loss: 0.7411 - val_accuracy: 0.8648
# Epoch 7/50
# 87/87 [==============================] - 106s 1s/step - loss: 0.7415 - accuracy: 0.8572 - val_loss: 0.7216 - val_accuracy: 0.8719
# Epoch 8/50
# 87/87 [==============================] - 105s 1s/step - loss: 0.7232 - accuracy: 0.8707 - val_loss: 0.7003 - val_accuracy: 0.8719
# Epoch 9/50
# 87/87 [==============================] - 106s 1s/step - loss: 0.7017 - accuracy: 0.8720 - val_loss: 0.6958 - val_accuracy: 0.8762
# Epoch 10/50
# 87/87 [==============================] - 106s 1s/step - loss: 0.6985 - accuracy: 0.8756 - val_loss: 0.6737 - val_accuracy: 0.8904
# Epoch 11/50
# 87/87 [==============================] - 107s 1s/step - loss: 0.6861 - accuracy: 0.8813 - val_loss: 0.7210 - val_accuracy: 0.8683
# Epoch 12/50
# 87/87 [==============================] - 107s 1s/step - loss: 0.6749 - accuracy: 0.8842 - val_loss: 0.6441 - val_accuracy: 0.8968
# Epoch 13/50
# 87/87 [==============================] - 106s 1s/step - loss: 0.6552 - accuracy: 0.8902 - val_loss: 0.6932 - val_accuracy: 0.8854
# Epoch 14/50
# 87/87 [==============================] - 106s 1s/step - loss: 0.6614 - accuracy: 0.8857 - val_loss: 0.6507 - val_accuracy: 0.9096
# Epoch 15/50
# 87/87 [==============================] - 106s 1s/step - loss: 0.6315 - accuracy: 0.9004 - val_loss: 0.6249 - val_accuracy: 0.8947
# Epoch 16/50
# 87/87 [==============================] - 106s 1s/step - loss: 0.6455 - accuracy: 0.8967 - val_loss: 0.6529 - val_accuracy: 0.8947
# Epoch 17/50
# 87/87 [==============================] - 106s 1s/step - loss: 0.6254 - accuracy: 0.9067 - val_loss: 0.6206 - val_accuracy: 0.8989
# Epoch 18/50
# 87/87 [==============================] - 105s 1s/step - loss: 0.6310 - accuracy: 0.8950 - val_loss: 0.6404 - val_accuracy: 0.9025
# Epoch 19/50
# 87/87 [==============================] - 104s 1s/step - loss: 0.6114 - accuracy: 0.9076 - val_loss: 0.6738 - val_accuracy: 0.8947
# Epoch 20/50
# 87/87 [==============================] - 104s 1s/step - loss: 0.6077 - accuracy: 0.9057 - val_loss: 0.6367 - val_accuracy: 0.8947
# Epoch 21/50
# 87/87 [==============================] - 104s 1s/step - loss: 0.5948 - accuracy: 0.9084 - val_loss: 0.6031 - val_accuracy: 0.9117
# Epoch 22/50
# 87/87 [==============================] - 105s 1s/step - loss: 0.5979 - accuracy: 0.9112 - val_loss: 0.5927 - val_accuracy: 0.9125
# Epoch 23/50
# 87/87 [==============================] - 105s 1s/step - loss: 0.5924 - accuracy: 0.9136 - val_loss: 0.6115 - val_accuracy: 0.9082
# Epoch 24/50
# 87/87 [==============================] - 105s 1s/step - loss: 0.5886 - accuracy: 0.9130 - val_loss: 0.6245 - val_accuracy: 0.9039
# Epoch 25/50
# 87/87 [==============================] - 105s 1s/step - loss: 0.5903 - accuracy: 0.9103 - val_loss: 0.6190 - val_accuracy: 0.9075
# Epoch 26/50
# 87/87 [==============================] - 105s 1s/step - loss: 0.5722 - accuracy: 0.9157 - val_loss: 0.5815 - val_accuracy: 0.9174
# Epoch 27/50
# 87/87 [==============================] - 104s 1s/step - loss: 0.5765 - accuracy: 0.9174 - val_loss: 0.5962 - val_accuracy: 0.9082
# Epoch 28/50
# 87/87 [==============================] - 104s 1s/step - loss: 0.5583 - accuracy: 0.9226 - val_loss: 0.5687 - val_accuracy: 0.9160
# Epoch 29/50
# 87/87 [==============================] - 104s 1s/step - loss: 0.5632 - accuracy: 0.9204 - val_loss: 0.6141 - val_accuracy: 0.9032
# Epoch 30/50
# 87/87 [==============================] - 105s 1s/step - loss: 0.5580 - accuracy: 0.9199 - val_loss: 0.5680 - val_accuracy: 0.9189
# Epoch 31/50
# 87/87 [==============================] - 105s 1s/step - loss: 0.5660 - accuracy: 0.9181 - val_loss: 0.5672 - val_accuracy: 0.9189
# Epoch 32/50
# 87/87 [==============================] - 104s 1s/step - loss: 0.5487 - accuracy: 0.9242 - val_loss: 0.6260 - val_accuracy: 0.9025
# Epoch 33/50
# 87/87 [==============================] - 105s 1s/step - loss: 0.5523 - accuracy: 0.9211 - val_loss: 0.6097 - val_accuracy: 0.8932
# Epoch 34/50
# 87/87 [==============================] - 105s 1s/step - loss: 0.5543 - accuracy: 0.9246 - val_loss: 0.5765 - val_accuracy: 0.9167
# Epoch 35/50
# 87/87 [==============================] - 105s 1s/step - loss: 0.5462 - accuracy: 0.9229 - val_loss: 0.5692 - val_accuracy: 0.9210
# Epoch 36/50
# 87/87 [==============================] - 104s 1s/step - loss: 0.5345 - accuracy: 0.9273 - val_loss: 0.5725 - val_accuracy: 0.9196
# Found 1405 validated image filenames belonging to 4 classes.
# 22/22 [==============================] - 21s 962ms/step - loss: 0.5684 - accuracy: 0.9210
# evaluate accuracy: 92.10%
# 22/22 [==============================] - 24s 947ms/step
# File fold_1_model.h5 berhasil diupload ke folder /gdrive/My Drive/SKRIPSI/Result/InceptionResNetV2_Coba3/
# File train_df_fold2.pkl berhasil diupload ke folder /gdrive/My Drive/SKRIPSI/Result/InceptionResNetV2_Coba3/
# File val_df_fold2.pkl berhasil diupload ke folder /gdrive/My Drive/SKRIPSI/Result/InceptionResNetV2_Coba3/
# Found 5618 validated image filenames belonging to 4 classes.
# Found 1405 validated image filenames belonging to 4 classes.
# Epoch 1/50
# 87/87 [==============================] - 120s 1s/step - loss: 1.2314 - accuracy: 0.6844 - val_loss: 1.1081 - val_accuracy: 0.7701
# Epoch 2/50
# 87/87 [==============================] - 105s 1s/step - loss: 0.9278 - accuracy: 0.8009 - val_loss: 0.8708 - val_accuracy: 0.8356
# Epoch 3/50
# 87/87 [==============================] - 105s 1s/step - loss: 0.8613 - accuracy: 0.8218 - val_loss: 0.8026 - val_accuracy: 0.8541
# Epoch 4/50
# 87/87 [==============================] - 104s 1s/step - loss: 0.8031 - accuracy: 0.8392 - val_loss: 0.7894 - val_accuracy: 0.8584
# Epoch 5/50
# 87/87 [==============================] - 106s 1s/step - loss: 0.7852 - accuracy: 0.8497 - val_loss: 0.7361 - val_accuracy: 0.8719
# Epoch 6/50
# 87/87 [==============================] - 105s 1s/step - loss: 0.7550 - accuracy: 0.8601 - val_loss: 0.7330 - val_accuracy: 0.8698
# Epoch 7/50
# 87/87 [==============================] - 106s 1s/step - loss: 0.7355 - accuracy: 0.8619 - val_loss: 0.7113 - val_accuracy: 0.8733
# Epoch 8/50
# 87/87 [==============================] - 105s 1s/step - loss: 0.7157 - accuracy: 0.8777 - val_loss: 0.6819 - val_accuracy: 0.8868
# Epoch 9/50
# 87/87 [==============================] - 107s 1s/step - loss: 0.6981 - accuracy: 0.8777 - val_loss: 0.6781 - val_accuracy: 0.8925
# Epoch 10/50
# 87/87 [==============================] - 105s 1s/step - loss: 0.6970 - accuracy: 0.8788 - val_loss: 0.6957 - val_accuracy: 0.8854
# Epoch 11/50
# 87/87 [==============================] - 106s 1s/step - loss: 0.6830 - accuracy: 0.8839 - val_loss: 0.6755 - val_accuracy: 0.8897
# Epoch 12/50
# 87/87 [==============================] - 106s 1s/step - loss: 0.6607 - accuracy: 0.8952 - val_loss: 0.6864 - val_accuracy: 0.8754
# Epoch 13/50
# 87/87 [==============================] - 106s 1s/step - loss: 0.6615 - accuracy: 0.8925 - val_loss: 0.6537 - val_accuracy: 0.8947
# Epoch 14/50
# 87/87 [==============================] - 105s 1s/step - loss: 0.6573 - accuracy: 0.8911 - val_loss: 0.6830 - val_accuracy: 0.8954
# Epoch 15/50
# 87/87 [==============================] - 106s 1s/step - loss: 0.6496 - accuracy: 0.8950 - val_loss: 0.6590 - val_accuracy: 0.8947
# Epoch 16/50
# 87/87 [==============================] - 106s 1s/step - loss: 0.6427 - accuracy: 0.8959 - val_loss: 0.6283 - val_accuracy: 0.8989
# Epoch 17/50
# 87/87 [==============================] - 104s 1s/step - loss: 0.6405 - accuracy: 0.8990 - val_loss: 0.6593 - val_accuracy: 0.8925
# Epoch 18/50
# 87/87 [==============================] - 104s 1s/step - loss: 0.6178 - accuracy: 0.9060 - val_loss: 0.6405 - val_accuracy: 0.9053
# Epoch 19/50
# 87/87 [==============================] - 104s 1s/step - loss: 0.6337 - accuracy: 0.8988 - val_loss: 0.6083 - val_accuracy: 0.9196
# Epoch 20/50
# 87/87 [==============================] - 106s 1s/step - loss: 0.6124 - accuracy: 0.9084 - val_loss: 0.6446 - val_accuracy: 0.9039
# Epoch 21/50
# 87/87 [==============================] - 105s 1s/step - loss: 0.5983 - accuracy: 0.9130 - val_loss: 0.5919 - val_accuracy: 0.9253
# Epoch 22/50
# 87/87 [==============================] - 105s 1s/step - loss: 0.6113 - accuracy: 0.9069 - val_loss: 0.6132 - val_accuracy: 0.9075
# Epoch 23/50
# 87/87 [==============================] - 105s 1s/step - loss: 0.5905 - accuracy: 0.9136 - val_loss: 0.6049 - val_accuracy: 0.9110
# Epoch 24/50
# 87/87 [==============================] - 105s 1s/step - loss: 0.5843 - accuracy: 0.9159 - val_loss: 0.5815 - val_accuracy: 0.9181
# Epoch 25/50
# 87/87 [==============================] - 104s 1s/step - loss: 0.5915 - accuracy: 0.9141 - val_loss: 0.6097 - val_accuracy: 0.9046
# Epoch 26/50
# 87/87 [==============================] - 105s 1s/step - loss: 0.5888 - accuracy: 0.9125 - val_loss: 0.5948 - val_accuracy: 0.9125
# Epoch 27/50
# 87/87 [==============================] - 104s 1s/step - loss: 0.5690 - accuracy: 0.9177 - val_loss: 0.5897 - val_accuracy: 0.9167
# Epoch 28/50
# 87/87 [==============================] - 104s 1s/step - loss: 0.5707 - accuracy: 0.9193 - val_loss: 0.6049 - val_accuracy: 0.9018
# Epoch 29/50
# 87/87 [==============================] - 104s 1s/step - loss: 0.5775 - accuracy: 0.9168 - val_loss: 0.6091 - val_accuracy: 0.9110
# Found 1405 validated image filenames belonging to 4 classes.
# 22/22 [==============================] - 21s 955ms/step - loss: 0.5987 - accuracy: 0.9096
# evaluate accuracy: 90.96%
# 22/22 [==============================] - 24s 946ms/step
# File fold_2_model.h5 berhasil diupload ke folder /gdrive/My Drive/SKRIPSI/Result/InceptionResNetV2_Coba3/
# File train_df_fold3.pkl berhasil diupload ke folder /gdrive/My Drive/SKRIPSI/Result/InceptionResNetV2_Coba3/
# File val_df_fold3.pkl berhasil diupload ke folder /gdrive/My Drive/SKRIPSI/Result/InceptionResNetV2_Coba3/
# Found 5618 validated image filenames belonging to 4 classes.
# Found 1405 validated image filenames belonging to 4 classes.
# Epoch 1/50
# 87/87 [==============================] - 121s 1s/step - loss: 1.2046 - accuracy: 0.6826 - val_loss: 1.0214 - val_accuracy: 0.7950
# Epoch 2/50
# 87/87 [==============================] - 104s 1s/step - loss: 0.9275 - accuracy: 0.7998 - val_loss: 0.8576 - val_accuracy: 0.8256
# Epoch 3/50
# 87/87 [==============================] - 104s 1s/step - loss: 0.8704 - accuracy: 0.8160 - val_loss: 0.7682 - val_accuracy: 0.8562
# Epoch 4/50
# 87/87 [==============================] - 105s 1s/step - loss: 0.8061 - accuracy: 0.8421 - val_loss: 0.7786 - val_accuracy: 0.8456
# Epoch 5/50
# 87/87 [==============================] - 105s 1s/step - loss: 0.7930 - accuracy: 0.8484 - val_loss: 0.7117 - val_accuracy: 0.8676
# Epoch 6/50
# 87/87 [==============================] - 104s 1s/step - loss: 0.7581 - accuracy: 0.8536 - val_loss: 0.7194 - val_accuracy: 0.8626
# Epoch 7/50
# 87/87 [==============================] - 105s 1s/step - loss: 0.7446 - accuracy: 0.8630 - val_loss: 0.6919 - val_accuracy: 0.8847
# Epoch 8/50
# 87/87 [==============================] - 105s 1s/step - loss: 0.7109 - accuracy: 0.8707 - val_loss: 0.6785 - val_accuracy: 0.8897
# Epoch 9/50
# 87/87 [==============================] - 106s 1s/step - loss: 0.7212 - accuracy: 0.8720 - val_loss: 0.7029 - val_accuracy: 0.8662
# Epoch 10/50
# 87/87 [==============================] - 105s 1s/step - loss: 0.6902 - accuracy: 0.8776 - val_loss: 0.7105 - val_accuracy: 0.8747
# Epoch 11/50
# 87/87 [==============================] - 105s 1s/step - loss: 0.6762 - accuracy: 0.8894 - val_loss: 0.6606 - val_accuracy: 0.8890
# Epoch 12/50
# 87/87 [==============================] - 104s 1s/step - loss: 0.6720 - accuracy: 0.8842 - val_loss: 0.6658 - val_accuracy: 0.8840
# Epoch 13/50
# 87/87 [==============================] - 104s 1s/step - loss: 0.6679 - accuracy: 0.8871 - val_loss: 0.6266 - val_accuracy: 0.8947
# Epoch 14/50
# 87/87 [==============================] - 104s 1s/step - loss: 0.6432 - accuracy: 0.8958 - val_loss: 0.6309 - val_accuracy: 0.9068
# Epoch 15/50
# 87/87 [==============================] - 105s 1s/step - loss: 0.6452 - accuracy: 0.8970 - val_loss: 0.6434 - val_accuracy: 0.8868
# Epoch 16/50
# 87/87 [==============================] - 104s 1s/step - loss: 0.6471 - accuracy: 0.8925 - val_loss: 0.6455 - val_accuracy: 0.8961
# Epoch 17/50
# 87/87 [==============================] - 104s 1s/step - loss: 0.6206 - accuracy: 0.9055 - val_loss: 0.6492 - val_accuracy: 0.8954
# Epoch 18/50
# 87/87 [==============================] - 106s 1s/step - loss: 0.6243 - accuracy: 0.9042 - val_loss: 0.6219 - val_accuracy: 0.9004
# Epoch 19/50
# 87/87 [==============================] - 104s 1s/step - loss: 0.6233 - accuracy: 0.9031 - val_loss: 0.6025 - val_accuracy: 0.9253
# Epoch 20/50
# 87/87 [==============================] - 104s 1s/step - loss: 0.6047 - accuracy: 0.9139 - val_loss: 0.6171 - val_accuracy: 0.9110
# Epoch 21/50
# 87/87 [==============================] - 105s 1s/step - loss: 0.6098 - accuracy: 0.9022 - val_loss: 0.6022 - val_accuracy: 0.9075
# Epoch 22/50
# 87/87 [==============================] - 104s 1s/step - loss: 0.6142 - accuracy: 0.9078 - val_loss: 0.6098 - val_accuracy: 0.9032
# Epoch 23/50
# 87/87 [==============================] - 105s 1s/step - loss: 0.6054 - accuracy: 0.9053 - val_loss: 0.6420 - val_accuracy: 0.8940
# Epoch 24/50
# 87/87 [==============================] - 104s 1s/step - loss: 0.5976 - accuracy: 0.9118 - val_loss: 0.5926 - val_accuracy: 0.9203
# Epoch 25/50
# 87/87 [==============================] - 105s 1s/step - loss: 0.5881 - accuracy: 0.9163 - val_loss: 0.5887 - val_accuracy: 0.9146
# Epoch 26/50
# 87/87 [==============================] - 104s 1s/step - loss: 0.5836 - accuracy: 0.9129 - val_loss: 0.5784 - val_accuracy: 0.9167
# Epoch 27/50
# 87/87 [==============================] - 106s 1s/step - loss: 0.5800 - accuracy: 0.9134 - val_loss: 0.5986 - val_accuracy: 0.9117
# Epoch 28/50
# 87/87 [==============================] - 108s 1s/step - loss: 0.5865 - accuracy: 0.9114 - val_loss: 0.5783 - val_accuracy: 0.9210
# Epoch 29/50
# 87/87 [==============================] - 107s 1s/step - loss: 0.5652 - accuracy: 0.9204 - val_loss: 0.6147 - val_accuracy: 0.9032
# Epoch 30/50
# 87/87 [==============================] - 108s 1s/step - loss: 0.5634 - accuracy: 0.9206 - val_loss: 0.6123 - val_accuracy: 0.9011
# Epoch 31/50
# 87/87 [==============================] - 109s 1s/step - loss: 0.5591 - accuracy: 0.9237 - val_loss: 0.5496 - val_accuracy: 0.9281
# Epoch 32/50
# 87/87 [==============================] - 110s 1s/step - loss: 0.5559 - accuracy: 0.9192 - val_loss: 0.6378 - val_accuracy: 0.8904
# Epoch 33/50
# 87/87 [==============================] - 110s 1s/step - loss: 0.5593 - accuracy: 0.9233 - val_loss: 0.5946 - val_accuracy: 0.9103
# Epoch 34/50
# 87/87 [==============================] - 109s 1s/step - loss: 0.5696 - accuracy: 0.9183 - val_loss: 0.5551 - val_accuracy: 0.9310
# Epoch 35/50
# 87/87 [==============================] - 108s 1s/step - loss: 0.5543 - accuracy: 0.9258 - val_loss: 0.5672 - val_accuracy: 0.9295
# Epoch 36/50
# 87/87 [==============================] - 107s 1s/step - loss: 0.5397 - accuracy: 0.9289 - val_loss: 0.5599 - val_accuracy: 0.9203
# Found 1405 validated image filenames belonging to 4 classes.
# 22/22 [==============================] - 22s 1s/step - loss: 0.5643 - accuracy: 0.9246
# evaluate accuracy: 92.46%
# 22/22 [==============================] - 25s 1000ms/step
# File fold_3_model.h5 berhasil diupload ke folder /gdrive/My Drive/SKRIPSI/Result/InceptionResNetV2_Coba3/
# File train_df_fold4.pkl berhasil diupload ke folder /gdrive/My Drive/SKRIPSI/Result/InceptionResNetV2_Coba3/
# File val_df_fold4.pkl berhasil diupload ke folder /gdrive/My Drive/SKRIPSI/Result/InceptionResNetV2_Coba3/
# Found 5619 validated image filenames belonging to 4 classes.
# Found 1404 validated image filenames belonging to 4 classes.
# Epoch 1/50
# 87/87 [==============================] - 127s 1s/step - loss: 1.2255 - accuracy: 0.6875 - val_loss: 1.0780 - val_accuracy: 0.7621
# Epoch 2/50
# 87/87 [==============================] - 111s 1s/step - loss: 0.9523 - accuracy: 0.7919 - val_loss: 0.8965 - val_accuracy: 0.8006
# Epoch 3/50
# 87/87 [==============================] - 110s 1s/step - loss: 0.8577 - accuracy: 0.8250 - val_loss: 0.7687 - val_accuracy: 0.8575
# Epoch 4/50
# 87/87 [==============================] - 109s 1s/step - loss: 0.8152 - accuracy: 0.8328 - val_loss: 0.7626 - val_accuracy: 0.8540
# Epoch 5/50
# 87/87 [==============================] - 107s 1s/step - loss: 0.7978 - accuracy: 0.8394 - val_loss: 0.7532 - val_accuracy: 0.8561
# Epoch 6/50
# 87/87 [==============================] - 110s 1s/step - loss: 0.7640 - accuracy: 0.8524 - val_loss: 0.7245 - val_accuracy: 0.8704
# Epoch 7/50
# 87/87 [==============================] - 108s 1s/step - loss: 0.7360 - accuracy: 0.8686 - val_loss: 0.6847 - val_accuracy: 0.8796
# Epoch 8/50
# 87/87 [==============================] - 110s 1s/step - loss: 0.7343 - accuracy: 0.8738 - val_loss: 0.6828 - val_accuracy: 0.8832
# Epoch 9/50
# 87/87 [==============================] - 109s 1s/step - loss: 0.7171 - accuracy: 0.8727 - val_loss: 0.6809 - val_accuracy: 0.8782
# Epoch 10/50
# 87/87 [==============================] - 111s 1s/step - loss: 0.7123 - accuracy: 0.8724 - val_loss: 0.6710 - val_accuracy: 0.8953
# Epoch 11/50
# 87/87 [==============================] - 109s 1s/step - loss: 0.6785 - accuracy: 0.8842 - val_loss: 0.6554 - val_accuracy: 0.8953
# Epoch 12/50
# 87/87 [==============================] - 109s 1s/step - loss: 0.6795 - accuracy: 0.8796 - val_loss: 0.6810 - val_accuracy: 0.8832
# Epoch 13/50
# 87/87 [==============================] - 109s 1s/step - loss: 0.6723 - accuracy: 0.8855 - val_loss: 0.6436 - val_accuracy: 0.8981
# Epoch 14/50
# 87/87 [==============================] - 108s 1s/step - loss: 0.6682 - accuracy: 0.8902 - val_loss: 0.6275 - val_accuracy: 0.8989
# Epoch 15/50
# 87/87 [==============================] - 107s 1s/step - loss: 0.6490 - accuracy: 0.8959 - val_loss: 0.6433 - val_accuracy: 0.9003
# Epoch 16/50
# 87/87 [==============================] - 108s 1s/step - loss: 0.6515 - accuracy: 0.8907 - val_loss: 0.6372 - val_accuracy: 0.8974
# Epoch 17/50
# 87/87 [==============================] - 106s 1s/step - loss: 0.6325 - accuracy: 0.8967 - val_loss: 0.6342 - val_accuracy: 0.8910
# Epoch 18/50
# 87/87 [==============================] - 105s 1s/step - loss: 0.6298 - accuracy: 0.9057 - val_loss: 0.6381 - val_accuracy: 0.8946
# Epoch 19/50
# 87/87 [==============================] - 105s 1s/step - loss: 0.6271 - accuracy: 0.8983 - val_loss: 0.5851 - val_accuracy: 0.9274
# Epoch 20/50
# 87/87 [==============================] - 105s 1s/step - loss: 0.6208 - accuracy: 0.9039 - val_loss: 0.6201 - val_accuracy: 0.8960
# Epoch 21/50
# 87/87 [==============================] - 104s 1s/step - loss: 0.6233 - accuracy: 0.9003 - val_loss: 0.6500 - val_accuracy: 0.8953
# Epoch 22/50
# 87/87 [==============================] - 105s 1s/step - loss: 0.6134 - accuracy: 0.8997 - val_loss: 0.6039 - val_accuracy: 0.9074
# Epoch 23/50
# 87/87 [==============================] - 106s 1s/step - loss: 0.5976 - accuracy: 0.9111 - val_loss: 0.6019 - val_accuracy: 0.9095
# Epoch 24/50
# 87/87 [==============================] - 106s 1s/step - loss: 0.6048 - accuracy: 0.9041 - val_loss: 0.6059 - val_accuracy: 0.8989
# Found 1404 validated image filenames belonging to 4 classes.
# 22/22 [==============================] - 21s 945ms/step - loss: 0.5878 - accuracy: 0.9138
# evaluate accuracy: 91.38%
# 22/22 [==============================] - 25s 957ms/step
# File fold_4_model.h5 berhasil diupload ke folder /gdrive/My Drive/SKRIPSI/Result/InceptionResNetV2_Coba3/
# File train_df_fold5.pkl berhasil diupload ke folder /gdrive/My Drive/SKRIPSI/Result/InceptionResNetV2_Coba3/
# File val_df_fold5.pkl berhasil diupload ke folder /gdrive/My Drive/SKRIPSI/Result/InceptionResNetV2_Coba3/
# Found 5619 validated image filenames belonging to 4 classes.
# Found 1404 validated image filenames belonging to 4 classes.
# Epoch 1/50
# 87/87 [==============================] - 121s 1s/step - loss: 1.1956 - accuracy: 0.6945 - val_loss: 1.0662 - val_accuracy: 0.7756
# Epoch 2/50
# 87/87 [==============================] - 105s 1s/step - loss: 0.9243 - accuracy: 0.8004 - val_loss: 0.8964 - val_accuracy: 0.8098
# Epoch 3/50
# 87/87 [==============================] - 105s 1s/step - loss: 0.8560 - accuracy: 0.8184 - val_loss: 0.7647 - val_accuracy: 0.8547
# Epoch 4/50
# 87/87 [==============================] - 104s 1s/step - loss: 0.8132 - accuracy: 0.8414 - val_loss: 0.7673 - val_accuracy: 0.8526
# Epoch 5/50
# 87/87 [==============================] - 106s 1s/step - loss: 0.7791 - accuracy: 0.8558 - val_loss: 0.7094 - val_accuracy: 0.8711
# Epoch 6/50
# 87/87 [==============================] - 105s 1s/step - loss: 0.7545 - accuracy: 0.8596 - val_loss: 0.7625 - val_accuracy: 0.8597
# Epoch 7/50
# 87/87 [==============================] - 106s 1s/step - loss: 0.7364 - accuracy: 0.8652 - val_loss: 0.7112 - val_accuracy: 0.8818
# Epoch 8/50
# 87/87 [==============================] - 107s 1s/step - loss: 0.7091 - accuracy: 0.8725 - val_loss: 0.6790 - val_accuracy: 0.8803
# Epoch 9/50
# 87/87 [==============================] - 105s 1s/step - loss: 0.7046 - accuracy: 0.8756 - val_loss: 0.7367 - val_accuracy: 0.8618
# Epoch 10/50
# 87/87 [==============================] - 106s 1s/step - loss: 0.6775 - accuracy: 0.8900 - val_loss: 0.6498 - val_accuracy: 0.8946
# Epoch 11/50
# 87/87 [==============================] - 107s 1s/step - loss: 0.6800 - accuracy: 0.8866 - val_loss: 0.6502 - val_accuracy: 0.8996
# Epoch 12/50
# 87/87 [==============================] - 106s 1s/step - loss: 0.6700 - accuracy: 0.8902 - val_loss: 0.6437 - val_accuracy: 0.9046
# Epoch 13/50
# 87/87 [==============================] - 106s 1s/step - loss: 0.6435 - accuracy: 0.8995 - val_loss: 0.6462 - val_accuracy: 0.9038
# Epoch 14/50
# 87/87 [==============================] - 105s 1s/step - loss: 0.6422 - accuracy: 0.8954 - val_loss: 0.6766 - val_accuracy: 0.8868
# Epoch 15/50
# 87/87 [==============================] - 105s 1s/step - loss: 0.6321 - accuracy: 0.8992 - val_loss: 0.6357 - val_accuracy: 0.8967
# Epoch 16/50
# 87/87 [==============================] - 105s 1s/step - loss: 0.6355 - accuracy: 0.8985 - val_loss: 0.6317 - val_accuracy: 0.9053
# Epoch 17/50
# 87/87 [==============================] - 104s 1s/step - loss: 0.6220 - accuracy: 0.9035 - val_loss: 0.6554 - val_accuracy: 0.9003
# Epoch 18/50
# 87/87 [==============================] - 103s 1s/step - loss: 0.6115 - accuracy: 0.9105 - val_loss: 0.6740 - val_accuracy: 0.8875
# Epoch 19/50
# 87/87 [==============================] - 104s 1s/step - loss: 0.6148 - accuracy: 0.9084 - val_loss: 0.6227 - val_accuracy: 0.9053
# Epoch 20/50
# 87/87 [==============================] - 105s 1s/step - loss: 0.6156 - accuracy: 0.9051 - val_loss: 0.5926 - val_accuracy: 0.9145
# Epoch 21/50
# 87/87 [==============================] - 106s 1s/step - loss: 0.6016 - accuracy: 0.9089 - val_loss: 0.6171 - val_accuracy: 0.9003
# Epoch 22/50
# 87/87 [==============================] - 105s 1s/step - loss: 0.5891 - accuracy: 0.9132 - val_loss: 0.6169 - val_accuracy: 0.9081
# Epoch 23/50
# 87/87 [==============================] - 106s 1s/step - loss: 0.5888 - accuracy: 0.9105 - val_loss: 0.6520 - val_accuracy: 0.8960
# Epoch 24/50
# 87/87 [==============================] - 109s 1s/step - loss: 0.5905 - accuracy: 0.9129 - val_loss: 0.6062 - val_accuracy: 0.9038
# Epoch 25/50
# 87/87 [==============================] - 107s 1s/step - loss: 0.5787 - accuracy: 0.9154 - val_loss: 0.6002 - val_accuracy: 0.9117
# Found 1404 validated image filenames belonging to 4 classes.
# 22/22 [==============================] - 21s 966ms/step - loss: 0.6061 - accuracy: 0.9046
# evaluate accuracy: 90.46%
# 22/22 [==============================] - 24s 958ms/step
# File fold_5_model.h5 berhasil diupload ke folder /gdrive/My Drive/SKRIPSI/Result/InceptionResNetV2_Coba3/
# Best Fold: 2
# Best Sensitivity: 0.9187745489341234

# %%
print('Avarage:')
df_results
# Out:
# Avarage:
#    fold  accuracy  precision  sensitivity  specificity  f1-score  time_taken
# 0     1  0.910320   0.909869     0.906340     0.881789  0.906979   64.093850
# 1     2  0.923132   0.921301     0.918775     0.886792  0.919433   51.698266
# 2     3  0.913879   0.915081     0.910170     0.876972  0.911029   65.487791
# 3     4  0.920228   0.917177     0.917833     0.943750  0.917111   44.032128
# 4     5  0.915954   0.913311     0.912572     0.949843  0.911782   47.939479

# %%
# # Tampilkan label sebelum di encode
# print("Label sebelum di encode: ", set(image_labels))
# # Tampilkan label setelah di encode
# print("Label setelah di encode: ", set(image_labels_encoded))

pd.DataFrame(df_results_class)
print('Class:')
df_results_class
# Out:
# Class:
#     fold       class  accuracy  precision  sensitivity  specificity  f1-score  \
# 0      1      glioma  0.910320   0.948454     0.851852     0.881789  0.897561
# 1      1  meningioma  0.910320   0.819767     0.857143     0.881789  0.838039
# 2      1     notumor  0.910320   0.992308     0.967500     0.881789  0.979747
# 3      1   pituitary  0.910320   0.878947     0.948864     0.881789  0.912568
# 4      2      glioma  0.923132   0.949495     0.870370     0.886792  0.908213
# 5      2  meningioma  0.923132   0.849850     0.860182     0.886792  0.854985
# 6      2     notumor  0.923132   0.980198     0.990000     0.886792  0.985075
# 7      2   pituitary  0.923132   0.905660     0.954545     0.886792  0.929461
# 8      3      glioma  0.913879   0.972028     0.855385     0.876972  0.909984
# 9      3  meningioma  0.913879   0.837278     0.860182     0.876972  0.848576
# 10     3     notumor  0.913879   0.984694     0.965000     0.876972  0.974747
# 11     3   pituitary  0.913879   0.866324     0.960114     0.876972  0.910811
# 12     4      glioma  0.920228   0.875362     0.932099     0.943750  0.902840
# 13     4  meningioma  0.920228   0.878594     0.835866     0.943750  0.856698
# 14     4     notumor  0.920228   0.979540     0.957500     0.943750  0.968394
# 15     4   pituitary  0.920228   0.935211     0.945869     0.943750  0.940510
# 16     5      glioma  0.915954   0.848739     0.935185     0.949843  0.889868
# 17     5  meningioma  0.915954   0.894915     0.802432     0.949843  0.846154
# 18     5     notumor  0.915954   0.977387     0.972500     0.949843  0.974937
# 19     5   pituitary  0.915954   0.932203     0.940171     0.949843  0.936170
#
#     time_taken
# 0    64.093850
# 1    64.093850
# 2    64.093850
# 3    64.093850
# 4    51.698266
# 5    51.698266
# 6    51.698266
# 7    51.698266
# 8    65.487791
# 9    65.487791
# 10   65.487791
# 11   65.487791
# 12   44.032128
# 13   44.032128
# 14   44.032128
# 15   44.032128
# 16   47.939479
# 17   47.939479
# 18   47.939479
# 19   47.939479

# %% [markdown]
# # **Section two:** We will start fine tunning

# %%
model.trainable = True

# Let's take a look to see how many layers are in the base model
print("Number of layers in the base model: ", len(model.layers))

# Fine-tune from this layer onwards
fine_tune_at = 100

# Freeze all the layers before the `fine_tune_at` layer
for layer in model.layers[:fine_tune_at]:
  layer.trainable = False

model.summary()
# Out:
# Number of layers in the base model:  788
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 299, 299, 3  0           []
#                                 )]
#
#  conv2d_812 (Conv2D)            (None, 149, 149, 32  864         ['input_5[0][0]']
#                                 )
#
#  batch_normalization_820 (Batch  (None, 149, 149, 32  96         ['conv2d_812[0][0]']
#  Normalization)                 )
#
#  activation_812 (Activation)    (None, 149, 149, 32  0           ['batch_normalization_820[0][0]']
#                                 )
#
#  conv2d_813 (Conv2D)            (None, 147, 147, 32  9216        ['activation_812[0][0]']
#                                 )
#
#  batch_normalization_821 (Batch  (None, 147, 147, 32  96         ['conv2d_813[0][0]']
#  Normalization)                 )
#
#  activation_813 (Activation)    (None, 147, 147, 32  0           ['batch_normalization_821[0][0]']
#                                 )
#
#  conv2d_814 (Conv2D)            (None, 147, 147, 64  18432       ['activation_813[0][0]']
#                                 )
#
#  batch_normalization_822 (Batch  (None, 147, 147, 64  192        ['conv2d_814[0][0]']
#  Normalization)                 )
#
#  activation_814 (Activation)    (None, 147, 147, 64  0           ['batch_normalization_822[0][0]']
#                                 )
#
#  max_pooling2d_16 (MaxPooling2D  (None, 73, 73, 64)  0           ['activation_814[0][0]']
#  )
#
#  conv2d_815 (Conv2D)            (None, 73, 73, 80)   5120        ['max_pooling2d_16[0][0]']
#
#  batch_normalization_823 (Batch  (None, 73, 73, 80)  240         ['conv2d_815[0][0]']
#  Normalization)
#
#  activation_815 (Activation)    (None, 73, 73, 80)   0           ['batch_normalization_823[0][0]']
#
#  conv2d_816 (Conv2D)            (None, 71, 71, 192)  138240      ['activation_815[0][0]']
#
#  batch_normalization_824 (Batch  (None, 71, 71, 192)  576        ['conv2d_816[0][0]']
#  Normalization)
#
#  activation_816 (Activation)    (None, 71, 71, 192)  0           ['batch_normalization_824[0][0]']
#
#  max_pooling2d_17 (MaxPooling2D  (None, 35, 35, 192)  0          ['activation_816[0][0]']
#  )
#
#  conv2d_820 (Conv2D)            (None, 35, 35, 64)   12288       ['max_pooling2d_17[0][0]']
#
#  batch_normalization_828 (Batch  (None, 35, 35, 64)  192         ['conv2d_820[0][0]']
#  Normalization)
#
#  activation_820 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_828[0][0]']
#
#  conv2d_818 (Conv2D)            (None, 35, 35, 48)   9216        ['max_pooling2d_17[0][0]']
#
#  conv2d_821 (Conv2D)            (None, 35, 35, 96)   55296       ['activation_820[0][0]']
#
#  batch_normalization_826 (Batch  (None, 35, 35, 48)  144         ['conv2d_818[0][0]']
#  Normalization)
#
#  batch_normalization_829 (Batch  (None, 35, 35, 96)  288         ['conv2d_821[0][0]']
#  Normalization)
#
#  activation_818 (Activation)    (None, 35, 35, 48)   0           ['batch_normalization_826[0][0]']
#
#  activation_821 (Activation)    (None, 35, 35, 96)   0           ['batch_normalization_829[0][0]']
#
#  average_pooling2d_4 (AveragePo  (None, 35, 35, 192)  0          ['max_pooling2d_17[0][0]']
#  oling2D)
#
#  conv2d_817 (Conv2D)            (None, 35, 35, 96)   18432       ['max_pooling2d_17[0][0]']
#
#  conv2d_819 (Conv2D)            (None, 35, 35, 64)   76800       ['activation_818[0][0]']
#
#  conv2d_822 (Conv2D)            (None, 35, 35, 96)   82944       ['activation_821[0][0]']
#
#  conv2d_823 (Conv2D)            (None, 35, 35, 64)   12288       ['average_pooling2d_4[0][0]']
#
#  batch_normalization_825 (Batch  (None, 35, 35, 96)  288         ['conv2d_817[0][0]']
#  Normalization)
#
#  batch_normalization_827 (Batch  (None, 35, 35, 64)  192         ['conv2d_819[0][0]']
#  Normalization)
#
#  batch_normalization_830 (Batch  (None, 35, 35, 96)  288         ['conv2d_822[0][0]']
#  Normalization)
#
#  batch_normalization_831 (Batch  (None, 35, 35, 64)  192         ['conv2d_823[0][0]']
#  Normalization)
#
#  activation_817 (Activation)    (None, 35, 35, 96)   0           ['batch_normalization_825[0][0]']
#
#  activation_819 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_827[0][0]']
#
#  activation_822 (Activation)    (None, 35, 35, 96)   0           ['batch_normalization_830[0][0]']
#
#  activation_823 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_831[0][0]']
#
#  mixed_5b (Concatenate)         (None, 35, 35, 320)  0           ['activation_817[0][0]',
#                                                                   'activation_819[0][0]',
#                                                                   'activation_822[0][0]',
#                                                                   'activation_823[0][0]']
#
#  conv2d_827 (Conv2D)            (None, 35, 35, 32)   10240       ['mixed_5b[0][0]']
#
#  batch_normalization_835 (Batch  (None, 35, 35, 32)  96          ['conv2d_827[0][0]']
#  Normalization)
#
#  activation_827 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_835[0][0]']
#
#  conv2d_825 (Conv2D)            (None, 35, 35, 32)   10240       ['mixed_5b[0][0]']
#
#  conv2d_828 (Conv2D)            (None, 35, 35, 48)   13824       ['activation_827[0][0]']
#
#  batch_normalization_833 (Batch  (None, 35, 35, 32)  96          ['conv2d_825[0][0]']
#  Normalization)
#
#  batch_normalization_836 (Batch  (None, 35, 35, 48)  144         ['conv2d_828[0][0]']
#  Normalization)
#
#  activation_825 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_833[0][0]']
#
#  activation_828 (Activation)    (None, 35, 35, 48)   0           ['batch_normalization_836[0][0]']
#
#  conv2d_824 (Conv2D)            (None, 35, 35, 32)   10240       ['mixed_5b[0][0]']
#
#  conv2d_826 (Conv2D)            (None, 35, 35, 32)   9216        ['activation_825[0][0]']
#
#  conv2d_829 (Conv2D)            (None, 35, 35, 64)   27648       ['activation_828[0][0]']
#
#  batch_normalization_832 (Batch  (None, 35, 35, 32)  96          ['conv2d_824[0][0]']
#  Normalization)
#
#  batch_normalization_834 (Batch  (None, 35, 35, 32)  96          ['conv2d_826[0][0]']
#  Normalization)
#
#  batch_normalization_837 (Batch  (None, 35, 35, 64)  192         ['conv2d_829[0][0]']
#  Normalization)
#
#  activation_824 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_832[0][0]']
#
#  activation_826 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_834[0][0]']
#
#  activation_829 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_837[0][0]']
#
#  block35_1_mixed (Concatenate)  (None, 35, 35, 128)  0           ['activation_824[0][0]',
#                                                                   'activation_826[0][0]',
#                                                                   'activation_829[0][0]']
#
#  block35_1_conv (Conv2D)        (None, 35, 35, 320)  41280       ['block35_1_mixed[0][0]']
#
#  custom_scale_layer_160 (Custom  (None, 35, 35, 320)  0          ['mixed_5b[0][0]',
#  ScaleLayer)                                                      'block35_1_conv[0][0]']
#
#  block35_1_ac (Activation)      (None, 35, 35, 320)  0           ['custom_scale_layer_160[0][0]']
#
#  conv2d_833 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_1_ac[0][0]']
#
#  batch_normalization_841 (Batch  (None, 35, 35, 32)  96          ['conv2d_833[0][0]']
#  Normalization)
#
#  activation_833 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_841[0][0]']
#
#  conv2d_831 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_1_ac[0][0]']
#
#  conv2d_834 (Conv2D)            (None, 35, 35, 48)   13824       ['activation_833[0][0]']
#
#  batch_normalization_839 (Batch  (None, 35, 35, 32)  96          ['conv2d_831[0][0]']
#  Normalization)
#
#  batch_normalization_842 (Batch  (None, 35, 35, 48)  144         ['conv2d_834[0][0]']
#  Normalization)
#
#  activation_831 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_839[0][0]']
#
#  activation_834 (Activation)    (None, 35, 35, 48)   0           ['batch_normalization_842[0][0]']
#
#  conv2d_830 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_1_ac[0][0]']
#
#  conv2d_832 (Conv2D)            (None, 35, 35, 32)   9216        ['activation_831[0][0]']
#
#  conv2d_835 (Conv2D)            (None, 35, 35, 64)   27648       ['activation_834[0][0]']
#
#  batch_normalization_838 (Batch  (None, 35, 35, 32)  96          ['conv2d_830[0][0]']
#  Normalization)
#
#  batch_normalization_840 (Batch  (None, 35, 35, 32)  96          ['conv2d_832[0][0]']
#  Normalization)
#
#  batch_normalization_843 (Batch  (None, 35, 35, 64)  192         ['conv2d_835[0][0]']
#  Normalization)
#
#  activation_830 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_838[0][0]']
#
#  activation_832 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_840[0][0]']
#
#  activation_835 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_843[0][0]']
#
#  block35_2_mixed (Concatenate)  (None, 35, 35, 128)  0           ['activation_830[0][0]',
#                                                                   'activation_832[0][0]',
#                                                                   'activation_835[0][0]']
#
#  block35_2_conv (Conv2D)        (None, 35, 35, 320)  41280       ['block35_2_mixed[0][0]']
#
#  custom_scale_layer_161 (Custom  (None, 35, 35, 320)  0          ['block35_1_ac[0][0]',
#  ScaleLayer)                                                      'block35_2_conv[0][0]']
#
#  block35_2_ac (Activation)      (None, 35, 35, 320)  0           ['custom_scale_layer_161[0][0]']
#
#  conv2d_839 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_2_ac[0][0]']
#
#  batch_normalization_847 (Batch  (None, 35, 35, 32)  96          ['conv2d_839[0][0]']
#  Normalization)
#
#  activation_839 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_847[0][0]']
#
#  conv2d_837 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_2_ac[0][0]']
#
#  conv2d_840 (Conv2D)            (None, 35, 35, 48)   13824       ['activation_839[0][0]']
#
#  batch_normalization_845 (Batch  (None, 35, 35, 32)  96          ['conv2d_837[0][0]']
#  Normalization)
#
#  batch_normalization_848 (Batch  (None, 35, 35, 48)  144         ['conv2d_840[0][0]']
#  Normalization)
#
#  activation_837 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_845[0][0]']
#
#  activation_840 (Activation)    (None, 35, 35, 48)   0           ['batch_normalization_848[0][0]']
#
#  conv2d_836 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_2_ac[0][0]']
#
#  conv2d_838 (Conv2D)            (None, 35, 35, 32)   9216        ['activation_837[0][0]']
#
#  conv2d_841 (Conv2D)            (None, 35, 35, 64)   27648       ['activation_840[0][0]']
#
#  batch_normalization_844 (Batch  (None, 35, 35, 32)  96          ['conv2d_836[0][0]']
#  Normalization)
#
#  batch_normalization_846 (Batch  (None, 35, 35, 32)  96          ['conv2d_838[0][0]']
#  Normalization)
#
#  batch_normalization_849 (Batch  (None, 35, 35, 64)  192         ['conv2d_841[0][0]']
#  Normalization)
#
#  activation_836 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_844[0][0]']
#
#  activation_838 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_846[0][0]']
#
#  activation_841 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_849[0][0]']
#
#  block35_3_mixed (Concatenate)  (None, 35, 35, 128)  0           ['activation_836[0][0]',
#                                                                   'activation_838[0][0]',
#                                                                   'activation_841[0][0]']
#
#  block35_3_conv (Conv2D)        (None, 35, 35, 320)  41280       ['block35_3_mixed[0][0]']
#
#  custom_scale_layer_162 (Custom  (None, 35, 35, 320)  0          ['block35_2_ac[0][0]',
#  ScaleLayer)                                                      'block35_3_conv[0][0]']
#
#  block35_3_ac (Activation)      (None, 35, 35, 320)  0           ['custom_scale_layer_162[0][0]']
#
#  conv2d_845 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_3_ac[0][0]']
#
#  batch_normalization_853 (Batch  (None, 35, 35, 32)  96          ['conv2d_845[0][0]']
#  Normalization)
#
#  activation_845 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_853[0][0]']
#
#  conv2d_843 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_3_ac[0][0]']
#
#  conv2d_846 (Conv2D)            (None, 35, 35, 48)   13824       ['activation_845[0][0]']
#
#  batch_normalization_851 (Batch  (None, 35, 35, 32)  96          ['conv2d_843[0][0]']
#  Normalization)
#
#  batch_normalization_854 (Batch  (None, 35, 35, 48)  144         ['conv2d_846[0][0]']
#  Normalization)
#
#  activation_843 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_851[0][0]']
#
#  activation_846 (Activation)    (None, 35, 35, 48)   0           ['batch_normalization_854[0][0]']
#
#  conv2d_842 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_3_ac[0][0]']
#
#  conv2d_844 (Conv2D)            (None, 35, 35, 32)   9216        ['activation_843[0][0]']
#
#  conv2d_847 (Conv2D)            (None, 35, 35, 64)   27648       ['activation_846[0][0]']
#
#  batch_normalization_850 (Batch  (None, 35, 35, 32)  96          ['conv2d_842[0][0]']
#  Normalization)
#
#  batch_normalization_852 (Batch  (None, 35, 35, 32)  96          ['conv2d_844[0][0]']
#  Normalization)
#
#  batch_normalization_855 (Batch  (None, 35, 35, 64)  192         ['conv2d_847[0][0]']
#  Normalization)
#
#  activation_842 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_850[0][0]']
#
#  activation_844 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_852[0][0]']
#
#  activation_847 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_855[0][0]']
#
#  block35_4_mixed (Concatenate)  (None, 35, 35, 128)  0           ['activation_842[0][0]',
#                                                                   'activation_844[0][0]',
#                                                                   'activation_847[0][0]']
#
#  block35_4_conv (Conv2D)        (None, 35, 35, 320)  41280       ['block35_4_mixed[0][0]']
#
#  custom_scale_layer_163 (Custom  (None, 35, 35, 320)  0          ['block35_3_ac[0][0]',
#  ScaleLayer)                                                      'block35_4_conv[0][0]']
#
#  block35_4_ac (Activation)      (None, 35, 35, 320)  0           ['custom_scale_layer_163[0][0]']
#
#  conv2d_851 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_4_ac[0][0]']
#
#  batch_normalization_859 (Batch  (None, 35, 35, 32)  96          ['conv2d_851[0][0]']
#  Normalization)
#
#  activation_851 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_859[0][0]']
#
#  conv2d_849 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_4_ac[0][0]']
#
#  conv2d_852 (Conv2D)            (None, 35, 35, 48)   13824       ['activation_851[0][0]']
#
#  batch_normalization_857 (Batch  (None, 35, 35, 32)  96          ['conv2d_849[0][0]']
#  Normalization)
#
#  batch_normalization_860 (Batch  (None, 35, 35, 48)  144         ['conv2d_852[0][0]']
#  Normalization)
#
#  activation_849 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_857[0][0]']
#
#  activation_852 (Activation)    (None, 35, 35, 48)   0           ['batch_normalization_860[0][0]']
#
#  conv2d_848 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_4_ac[0][0]']
#
#  conv2d_850 (Conv2D)            (None, 35, 35, 32)   9216        ['activation_849[0][0]']
#
#  conv2d_853 (Conv2D)            (None, 35, 35, 64)   27648       ['activation_852[0][0]']
#
#  batch_normalization_856 (Batch  (None, 35, 35, 32)  96          ['conv2d_848[0][0]']
#  Normalization)
#
#  batch_normalization_858 (Batch  (None, 35, 35, 32)  96          ['conv2d_850[0][0]']
#  Normalization)
#
#  batch_normalization_861 (Batch  (None, 35, 35, 64)  192         ['conv2d_853[0][0]']
#  Normalization)
#
#  activation_848 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_856[0][0]']
#
#  activation_850 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_858[0][0]']
#
#  activation_853 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_861[0][0]']
#
#  block35_5_mixed (Concatenate)  (None, 35, 35, 128)  0           ['activation_848[0][0]',
#                                                                   'activation_850[0][0]',
#                                                                   'activation_853[0][0]']
#
#  block35_5_conv (Conv2D)        (None, 35, 35, 320)  41280       ['block35_5_mixed[0][0]']
#
#  custom_scale_layer_164 (Custom  (None, 35, 35, 320)  0          ['block35_4_ac[0][0]',
#  ScaleLayer)                                                      'block35_5_conv[0][0]']
#
#  block35_5_ac (Activation)      (None, 35, 35, 320)  0           ['custom_scale_layer_164[0][0]']
#
#  conv2d_857 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_5_ac[0][0]']
#
#  batch_normalization_865 (Batch  (None, 35, 35, 32)  96          ['conv2d_857[0][0]']
#  Normalization)
#
#  activation_857 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_865[0][0]']
#
#  conv2d_855 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_5_ac[0][0]']
#
#  conv2d_858 (Conv2D)            (None, 35, 35, 48)   13824       ['activation_857[0][0]']
#
#  batch_normalization_863 (Batch  (None, 35, 35, 32)  96          ['conv2d_855[0][0]']
#  Normalization)
#
#  batch_normalization_866 (Batch  (None, 35, 35, 48)  144         ['conv2d_858[0][0]']
#  Normalization)
#
#  activation_855 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_863[0][0]']
#
#  activation_858 (Activation)    (None, 35, 35, 48)   0           ['batch_normalization_866[0][0]']
#
#  conv2d_854 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_5_ac[0][0]']
#
#  conv2d_856 (Conv2D)            (None, 35, 35, 32)   9216        ['activation_855[0][0]']
#
#  conv2d_859 (Conv2D)            (None, 35, 35, 64)   27648       ['activation_858[0][0]']
#
#  batch_normalization_862 (Batch  (None, 35, 35, 32)  96          ['conv2d_854[0][0]']
#  Normalization)
#
#  batch_normalization_864 (Batch  (None, 35, 35, 32)  96          ['conv2d_856[0][0]']
#  Normalization)
#
#  batch_normalization_867 (Batch  (None, 35, 35, 64)  192         ['conv2d_859[0][0]']
#  Normalization)
#
#  activation_854 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_862[0][0]']
#
#  activation_856 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_864[0][0]']
#
#  activation_859 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_867[0][0]']
#
#  block35_6_mixed (Concatenate)  (None, 35, 35, 128)  0           ['activation_854[0][0]',
#                                                                   'activation_856[0][0]',
#                                                                   'activation_859[0][0]']
#
#  block35_6_conv (Conv2D)        (None, 35, 35, 320)  41280       ['block35_6_mixed[0][0]']
#
#  custom_scale_layer_165 (Custom  (None, 35, 35, 320)  0          ['block35_5_ac[0][0]',
#  ScaleLayer)                                                      'block35_6_conv[0][0]']
#
#  block35_6_ac (Activation)      (None, 35, 35, 320)  0           ['custom_scale_layer_165[0][0]']
#
#  conv2d_863 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_6_ac[0][0]']
#
#  batch_normalization_871 (Batch  (None, 35, 35, 32)  96          ['conv2d_863[0][0]']
#  Normalization)
#
#  activation_863 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_871[0][0]']
#
#  conv2d_861 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_6_ac[0][0]']
#
#  conv2d_864 (Conv2D)            (None, 35, 35, 48)   13824       ['activation_863[0][0]']
#
#  batch_normalization_869 (Batch  (None, 35, 35, 32)  96          ['conv2d_861[0][0]']
#  Normalization)
#
#  batch_normalization_872 (Batch  (None, 35, 35, 48)  144         ['conv2d_864[0][0]']
#  Normalization)
#
#  activation_861 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_869[0][0]']
#
#  activation_864 (Activation)    (None, 35, 35, 48)   0           ['batch_normalization_872[0][0]']
#
#  conv2d_860 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_6_ac[0][0]']
#
#  conv2d_862 (Conv2D)            (None, 35, 35, 32)   9216        ['activation_861[0][0]']
#
#  conv2d_865 (Conv2D)            (None, 35, 35, 64)   27648       ['activation_864[0][0]']
#
#  batch_normalization_868 (Batch  (None, 35, 35, 32)  96          ['conv2d_860[0][0]']
#  Normalization)
#
#  batch_normalization_870 (Batch  (None, 35, 35, 32)  96          ['conv2d_862[0][0]']
#  Normalization)
#
#  batch_normalization_873 (Batch  (None, 35, 35, 64)  192         ['conv2d_865[0][0]']
#  Normalization)
#
#  activation_860 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_868[0][0]']
#
#  activation_862 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_870[0][0]']
#
#  activation_865 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_873[0][0]']
#
#  block35_7_mixed (Concatenate)  (None, 35, 35, 128)  0           ['activation_860[0][0]',
#                                                                   'activation_862[0][0]',
#                                                                   'activation_865[0][0]']
#
#  block35_7_conv (Conv2D)        (None, 35, 35, 320)  41280       ['block35_7_mixed[0][0]']
#
#  custom_scale_layer_166 (Custom  (None, 35, 35, 320)  0          ['block35_6_ac[0][0]',
#  ScaleLayer)                                                      'block35_7_conv[0][0]']
#
#  block35_7_ac (Activation)      (None, 35, 35, 320)  0           ['custom_scale_layer_166[0][0]']
#
#  conv2d_869 (Conv2D)            (None, 35, 35, 32)   10240       ['block35_7_ac[0][0]']
#
#  batch_normalization_877 (Batch  (None, 35, 35, 32)  96          ['conv2d_869[0][0]']
# ...
#  custom_scale_layer_196 (Custom  (None, 8, 8, 2080)  0           ['block8_6_ac[0][0]',
#  ScaleLayer)                                                      'block8_7_conv[0][0]']
#
#  block8_7_ac (Activation)       (None, 8, 8, 2080)   0           ['custom_scale_layer_196[0][0]']
#
#  conv2d_1004 (Conv2D)           (None, 8, 8, 192)    399360      ['block8_7_ac[0][0]']
#
#  batch_normalization_1012 (Batc  (None, 8, 8, 192)   576         ['conv2d_1004[0][0]']
#  hNormalization)
#
#  activation_1004 (Activation)   (None, 8, 8, 192)    0           ['batch_normalization_1012[0][0]'
#                                                                  ]
#
#  conv2d_1005 (Conv2D)           (None, 8, 8, 224)    129024      ['activation_1004[0][0]']
#
#  batch_normalization_1013 (Batc  (None, 8, 8, 224)   672         ['conv2d_1005[0][0]']
#  hNormalization)
#
#  activation_1005 (Activation)   (None, 8, 8, 224)    0           ['batch_normalization_1013[0][0]'
#                                                                  ]
#
#  conv2d_1003 (Conv2D)           (None, 8, 8, 192)    399360      ['block8_7_ac[0][0]']
#
#  conv2d_1006 (Conv2D)           (None, 8, 8, 256)    172032      ['activation_1005[0][0]']
#
#  batch_normalization_1011 (Batc  (None, 8, 8, 192)   576         ['conv2d_1003[0][0]']
#  hNormalization)
#
#  batch_normalization_1014 (Batc  (None, 8, 8, 256)   768         ['conv2d_1006[0][0]']
#  hNormalization)
#
#  activation_1003 (Activation)   (None, 8, 8, 192)    0           ['batch_normalization_1011[0][0]'
#                                                                  ]
#
#  activation_1006 (Activation)   (None, 8, 8, 256)    0           ['batch_normalization_1014[0][0]'
#                                                                  ]
#
#  block8_8_mixed (Concatenate)   (None, 8, 8, 448)    0           ['activation_1003[0][0]',
#                                                                   'activation_1006[0][0]']
#
#  block8_8_conv (Conv2D)         (None, 8, 8, 2080)   933920      ['block8_8_mixed[0][0]']
#
#  custom_scale_layer_197 (Custom  (None, 8, 8, 2080)  0           ['block8_7_ac[0][0]',
#  ScaleLayer)                                                      'block8_8_conv[0][0]']
#
#  block8_8_ac (Activation)       (None, 8, 8, 2080)   0           ['custom_scale_layer_197[0][0]']
#
#  conv2d_1008 (Conv2D)           (None, 8, 8, 192)    399360      ['block8_8_ac[0][0]']
#
#  batch_normalization_1016 (Batc  (None, 8, 8, 192)   576         ['conv2d_1008[0][0]']
#  hNormalization)
#
#  activation_1008 (Activation)   (None, 8, 8, 192)    0           ['batch_normalization_1016[0][0]'
#                                                                  ]
#
#  conv2d_1009 (Conv2D)           (None, 8, 8, 224)    129024      ['activation_1008[0][0]']
#
#  batch_normalization_1017 (Batc  (None, 8, 8, 224)   672         ['conv2d_1009[0][0]']
#  hNormalization)
#
#  activation_1009 (Activation)   (None, 8, 8, 224)    0           ['batch_normalization_1017[0][0]'
#                                                                  ]
#
#  conv2d_1007 (Conv2D)           (None, 8, 8, 192)    399360      ['block8_8_ac[0][0]']
#
#  conv2d_1010 (Conv2D)           (None, 8, 8, 256)    172032      ['activation_1009[0][0]']
#
#  batch_normalization_1015 (Batc  (None, 8, 8, 192)   576         ['conv2d_1007[0][0]']
#  hNormalization)
#
#  batch_normalization_1018 (Batc  (None, 8, 8, 256)   768         ['conv2d_1010[0][0]']
#  hNormalization)
#
#  activation_1007 (Activation)   (None, 8, 8, 192)    0           ['batch_normalization_1015[0][0]'
#                                                                  ]
#
#  activation_1010 (Activation)   (None, 8, 8, 256)    0           ['batch_normalization_1018[0][0]'
#                                                                  ]
#
#  block8_9_mixed (Concatenate)   (None, 8, 8, 448)    0           ['activation_1007[0][0]',
#                                                                   'activation_1010[0][0]']
#
#  block8_9_conv (Conv2D)         (None, 8, 8, 2080)   933920      ['block8_9_mixed[0][0]']
#
#  custom_scale_layer_198 (Custom  (None, 8, 8, 2080)  0           ['block8_8_ac[0][0]',
#  ScaleLayer)                                                      'block8_9_conv[0][0]']
#
#  block8_9_ac (Activation)       (None, 8, 8, 2080)   0           ['custom_scale_layer_198[0][0]']
#
#  conv2d_1012 (Conv2D)           (None, 8, 8, 192)    399360      ['block8_9_ac[0][0]']
#
#  batch_normalization_1020 (Batc  (None, 8, 8, 192)   576         ['conv2d_1012[0][0]']
#  hNormalization)
#
#  activation_1012 (Activation)   (None, 8, 8, 192)    0           ['batch_normalization_1020[0][0]'
#                                                                  ]
#
#  conv2d_1013 (Conv2D)           (None, 8, 8, 224)    129024      ['activation_1012[0][0]']
#
#  batch_normalization_1021 (Batc  (None, 8, 8, 224)   672         ['conv2d_1013[0][0]']
#  hNormalization)
#
#  activation_1013 (Activation)   (None, 8, 8, 224)    0           ['batch_normalization_1021[0][0]'
#                                                                  ]
#
#  conv2d_1011 (Conv2D)           (None, 8, 8, 192)    399360      ['block8_9_ac[0][0]']
#
#  conv2d_1014 (Conv2D)           (None, 8, 8, 256)    172032      ['activation_1013[0][0]']
#
#  batch_normalization_1019 (Batc  (None, 8, 8, 192)   576         ['conv2d_1011[0][0]']
#  hNormalization)
#
#  batch_normalization_1022 (Batc  (None, 8, 8, 256)   768         ['conv2d_1014[0][0]']
#  hNormalization)
#
#  activation_1011 (Activation)   (None, 8, 8, 192)    0           ['batch_normalization_1019[0][0]'
#                                                                  ]
#
#  activation_1014 (Activation)   (None, 8, 8, 256)    0           ['batch_normalization_1022[0][0]'
#                                                                  ]
#
#  block8_10_mixed (Concatenate)  (None, 8, 8, 448)    0           ['activation_1011[0][0]',
#                                                                   'activation_1014[0][0]']
#
#  block8_10_conv (Conv2D)        (None, 8, 8, 2080)   933920      ['block8_10_mixed[0][0]']
#
#  custom_scale_layer_199 (Custom  (None, 8, 8, 2080)  0           ['block8_9_ac[0][0]',
#  ScaleLayer)                                                      'block8_10_conv[0][0]']
#
#  conv_7b (Conv2D)               (None, 8, 8, 1536)   3194880     ['custom_scale_layer_199[0][0]']
#
#  conv_7b_bn (BatchNormalization  (None, 8, 8, 1536)  4608        ['conv_7b[0][0]']
#  )
#
#  conv_7b_ac (Activation)        (None, 8, 8, 1536)   0           ['conv_7b_bn[0][0]']
#
#  global_average_pooling2d_4 (Gl  (None, 1536)        0           ['conv_7b_ac[0][0]']
#  obalAveragePooling2D)
#
#  dense_12 (Dense)               (None, 512)          786944      ['global_average_pooling2d_4[0][0
#                                                                  ]']
#
#  batch_normalization_1023 (Batc  (None, 512)         2048        ['dense_12[0][0]']
#  hNormalization)
#
#  dropout_8 (Dropout)            (None, 512)          0           ['batch_normalization_1023[0][0]'
#                                                                  ]
#
#  dense_13 (Dense)               (None, 256)          131328      ['dropout_8[0][0]']
#
#  batch_normalization_1024 (Batc  (None, 256)         1024        ['dense_13[0][0]']
#  hNormalization)
#
#  dropout_9 (Dropout)            (None, 256)          0           ['batch_normalization_1024[0][0]'
#                                                                  ]
#
#  dense_14 (Dense)               (None, 4)            1028        ['dropout_9[0][0]']
#
# ==================================================================================================
# Total params: 55,259,108
# Trainable params: 54,429,460
# Non-trainable params: 829,648
# __________________________________________________________________________________________________

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-5) #PASTIKAN MENGGUNAKAN OPTIMIZER TERBAIK
# compile the model
model.compile(optimizer=optimizer,
          loss='categorical_crossentropy',
          metrics=['accuracy'])

# %%
fine_tune_epochs = 10 #GANTI JIKA BUKAN TESTINg
total_epochs =  epochs_initial + fine_tune_epochs

history_fine = model.fit(train_generator_initial,
                         epochs=total_epochs,
                         initial_epoch=history.epoch[-1],
                         validation_data=val_generator_initial,callbacks=[early_stop])
# Out:
# Epoch 25/60
# 88/88 [==============================] - 199s 1s/step - loss: 1.0955 - accuracy: 0.7471 - val_loss: 0.6925 - val_accuracy: 0.8825
# Epoch 26/60
# 88/88 [==============================] - 108s 1s/step - loss: 0.7946 - accuracy: 0.8475 - val_loss: 0.7221 - val_accuracy: 0.8739
# Epoch 27/60
# 88/88 [==============================] - 107s 1s/step - loss: 0.6855 - accuracy: 0.8813 - val_loss: 0.6549 - val_accuracy: 0.8853
# Epoch 28/60
# 88/88 [==============================] - 106s 1s/step - loss: 0.6259 - accuracy: 0.8987 - val_loss: 0.6018 - val_accuracy: 0.9110
# Epoch 29/60
# 88/88 [==============================] - 106s 1s/step - loss: 0.5821 - accuracy: 0.9171 - val_loss: 0.5555 - val_accuracy: 0.9217
# Epoch 30/60
# 88/88 [==============================] - 106s 1s/step - loss: 0.5532 - accuracy: 0.9253 - val_loss: 0.5243 - val_accuracy: 0.9409
# Epoch 31/60
# 88/88 [==============================] - 106s 1s/step - loss: 0.5277 - accuracy: 0.9326 - val_loss: 0.5076 - val_accuracy: 0.9444
# Epoch 32/60
# 88/88 [==============================] - 105s 1s/step - loss: 0.4993 - accuracy: 0.9402 - val_loss: 0.4918 - val_accuracy: 0.9516
# Epoch 33/60
# 88/88 [==============================] - 105s 1s/step - loss: 0.4848 - accuracy: 0.9486 - val_loss: 0.4811 - val_accuracy: 0.9551
# Epoch 34/60
# 88/88 [==============================] - 106s 1s/step - loss: 0.4762 - accuracy: 0.9530 - val_loss: 0.4739 - val_accuracy: 0.9530
# Epoch 35/60
# 88/88 [==============================] - 106s 1s/step - loss: 0.4608 - accuracy: 0.9608 - val_loss: 0.4556 - val_accuracy: 0.9601
# Epoch 36/60
# 88/88 [==============================] - 106s 1s/step - loss: 0.4469 - accuracy: 0.9648 - val_loss: 0.4519 - val_accuracy: 0.9573
# Epoch 37/60
# 88/88 [==============================] - 106s 1s/step - loss: 0.4418 - accuracy: 0.9671 - val_loss: 0.4483 - val_accuracy: 0.9587
# Epoch 38/60
# 88/88 [==============================] - 106s 1s/step - loss: 0.4273 - accuracy: 0.9713 - val_loss: 0.4348 - val_accuracy: 0.9623
# Epoch 39/60
# 88/88 [==============================] - 106s 1s/step - loss: 0.4172 - accuracy: 0.9738 - val_loss: 0.4301 - val_accuracy: 0.9672
# Epoch 40/60
# 88/88 [==============================] - 105s 1s/step - loss: 0.4122 - accuracy: 0.9749 - val_loss: 0.4320 - val_accuracy: 0.9701
# Epoch 41/60
# 88/88 [==============================] - 106s 1s/step - loss: 0.4073 - accuracy: 0.9762 - val_loss: 0.4264 - val_accuracy: 0.9701
# Epoch 42/60
# 88/88 [==============================] - 109s 1s/step - loss: 0.4020 - accuracy: 0.9767 - val_loss: 0.4019 - val_accuracy: 0.9744
# Epoch 43/60
# 88/88 [==============================] - 107s 1s/step - loss: 0.3968 - accuracy: 0.9801 - val_loss: 0.3913 - val_accuracy: 0.9793
# Epoch 44/60
# 88/88 [==============================] - 106s 1s/step - loss: 0.3924 - accuracy: 0.9824 - val_loss: 0.3993 - val_accuracy: 0.9758
# Epoch 45/60
# 88/88 [==============================] - 107s 1s/step - loss: 0.3830 - accuracy: 0.9845 - val_loss: 0.4116 - val_accuracy: 0.9751
# Epoch 46/60
# 88/88 [==============================] - 107s 1s/step - loss: 0.3855 - accuracy: 0.9827 - val_loss: 0.3941 - val_accuracy: 0.9786
# Epoch 47/60
# 88/88 [==============================] - 106s 1s/step - loss: 0.3748 - accuracy: 0.9879 - val_loss: 0.3870 - val_accuracy: 0.9836
# Epoch 48/60
# 88/88 [==============================] - 107s 1s/step - loss: 0.3755 - accuracy: 0.9859 - val_loss: 0.3898 - val_accuracy: 0.9822
# Epoch 49/60
# 88/88 [==============================] - 108s 1s/step - loss: 0.3764 - accuracy: 0.9852 - val_loss: 0.3896 - val_accuracy: 0.9808
# Epoch 50/60
# 88/88 [==============================] - 108s 1s/step - loss: 0.3713 - accuracy: 0.9859 - val_loss: 0.3883 - val_accuracy: 0.9786
# Epoch 51/60
# 88/88 [==============================] - 110s 1s/step - loss: 0.3590 - accuracy: 0.9916 - val_loss: 0.3850 - val_accuracy: 0.9793
# Epoch 52/60
# 88/88 [==============================] - 111s 1s/step - loss: 0.3624 - accuracy: 0.9904 - val_loss: 0.3869 - val_accuracy: 0.9815
# Epoch 53/60
# 88/88 [==============================] - 110s 1s/step - loss: 0.3558 - accuracy: 0.9918 - val_loss: 0.3844 - val_accuracy: 0.9772
# Epoch 54/60
# 88/88 [==============================] - 109s 1s/step - loss: 0.3546 - accuracy: 0.9925 - val_loss: 0.3731 - val_accuracy: 0.9858
# Epoch 55/60
# 88/88 [==============================] - 109s 1s/step - loss: 0.3602 - accuracy: 0.9893 - val_loss: 0.3781 - val_accuracy: 0.9836
# Epoch 56/60
# 88/88 [==============================] - 110s 1s/step - loss: 0.3491 - accuracy: 0.9915 - val_loss: 0.3831 - val_accuracy: 0.9793
# Epoch 57/60
# 88/88 [==============================] - 108s 1s/step - loss: 0.3472 - accuracy: 0.9923 - val_loss: 0.3676 - val_accuracy: 0.9865
# Epoch 58/60
# 88/88 [==============================] - 108s 1s/step - loss: 0.3483 - accuracy: 0.9925 - val_loss: 0.3674 - val_accuracy: 0.9850
# Epoch 59/60
# 88/88 [==============================] - 108s 1s/step - loss: 0.3416 - accuracy: 0.9945 - val_loss: 0.3701 - val_accuracy: 0.9850
# Epoch 60/60
# 88/88 [==============================] - 109s 1s/step - loss: 0.3406 - accuracy: 0.9941 - val_loss: 0.3640 - val_accuracy: 0.9865

# %%
results_fine = []
results_class_fine = []

toc = time.time()

with open(f'val_df_fold{best_fold}.pkl', 'rb') as f:
    val_df_fine = pickle.load(f)

# Evaluasi model pada validasi set
val_generator = datagen.flow_from_dataframe(dataframe=val_df_fine,
                                        x_col='path',
                                        y_col='label',
                                        color_mode='rgb',
                                        batch_size=batchsize_initial,
                                        class_mode="categorical",
                                        shuffle=False)

predictions = model.predict(val_generator)
y_true = val_generator.labels
y_pred = np.argmax(predictions, axis=1)

# hitung confusion matrix dan hasil evaluasi per kelas
cm = confusion_matrix(y_true, y_pred)
class_names = train_generator_initial.class_indices.keys()
report = classification_report(y_true, y_pred, target_names=class_names, output_dict=True)

# hitung specificity 
tn, fp, fn, tp = cm[0][0], cm[0][1], cm[1][0], cm[1][1]
specificity = []
for i in range(len(class_names)):
    spec = tn / (tn + fp)
    specificity.append(spec)

# tampilkan confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title(f'Confusion Matrix After Fine Tune')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, average='macro')
sensitivity_ava = recall_score(y_true, y_pred, average='macro')
f1 = f1_score(y_true, y_pred, average='macro')
time_taken = toc - tic

# tampilkan hasil evaluasi per kelas
for i, name in enumerate(class_names):
    results_class_fine.append({'class': name,'accuracy': accuracy,'precision': report[name]['precision'],
                              'sensitivity': report[name]['recall'], 'specificity': specificity[i],
                                'f1-score': report[name]['f1-score'], 'time_taken': time_taken/60.0})

results_fine.append({'accuracy': accuracy,
            'precision': precision,
            'sensitivity': sensitivity_ava,
            'specificity': np.mean(specificity),  # menambahkan rata-rata specificity untuk setiap kelas
            'f1-score': f1,
            'time_taken': time_taken/60.0})

acc += history_fine.history['accuracy']
val_acc += history_fine.history['val_accuracy']

loss += history_fine.history['loss']
val_loss += history_fine.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.ylim([0.8, 1])
plt.plot([epochs_initial-1,epochs_initial-1],
          plt.ylim(), label='Start Fine Tuning')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy InceptionResNetV2 After Fine Tune')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.ylim([0, 1.0])
plt.plot([epochs_initial-1,epochs_initial-1],
         plt.ylim(), label='Start Fine Tuning')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss InceptionResNetV2 After Fine Tune')
plt.xlabel('epoch')
plt.show()

# Konversi list results ke dalam dataframe pandas
df_results_fine = pd.DataFrame(results_fine, columns=['accuracy','precision', 'sensitivity','specificity', 'f1-score', 'time_taken'])
df_results_class_fine = pd.DataFrame(results_class_fine, columns=['class','accuracy', 'precision','sensitivity', 'specificity', 'f1-score', 'time_taken'])
# Tampilkan hasil evaluasi dalam bentuk tabel
pd.DataFrame(df_results_fine)
pd.DataFrame(df_results_class_fine)
print('Avarage:')
df_results_fine
# Out:
# Found 1405 validated image filenames belonging to 4 classes.
# 22/22 [==============================] - 24s 944ms/step
# Avarage:
#    accuracy  precision  sensitivity  specificity  f1-score  time_taken
# 0  0.996441   0.996424      0.99625          1.0   0.99633  115.375841

# %%
# evaluation on validation data
scores = model.evaluate(val_generator)
print("%s%s: %.2f%%" % ("evaluate ",model.metrics_names[1], scores[1]*100))
# Out:
# 22/22 [==============================] - 28s 1s/step - loss: 0.3305 - accuracy: 0.9972
# evaluate accuracy: 99.72%

# %%
# # Tampilkan label sebelum di encode
# print("Label sebelum di encode: ", set(image_labels))
# # Tampilkan label setelah di encode
# print("Label setelah di encode: ", set(image_labels_encoded))

pd.DataFrame(df_results_class_fine)
print('Class:')
df_results_class_fine
# Out:
# Class:
#         class  accuracy  precision  sensitivity  specificity  f1-score  \
# 0      glioma  0.996441   0.996923     1.000000          1.0  0.998459
# 1  meningioma  0.996441   0.996933     0.987842          1.0  0.992366
# 2     notumor  0.996441   0.997506     1.000000          1.0  0.998752
# 3   pituitary  0.996441   0.994334     0.997159          1.0  0.995745
#
#    time_taken
# 0  115.375841
# 1  115.375841
# 2  115.375841
# 3  115.375841

# %%
model.save(f'model_InceptionResNetV2_final.h5')
upload_drive(f'model_InceptionResNetV2_final.h5',RESULT_FOLDER)

# %%
df_results_class
# Out:
#     fold       class  accuracy  precision  sensitivity  specificity  f1-score  \
# 0      1      glioma  0.910320   0.948454     0.851852     0.881789  0.897561
# 1      1  meningioma  0.910320   0.819767     0.857143     0.881789  0.838039
# 2      1     notumor  0.910320   0.992308     0.967500     0.881789  0.979747
# 3      1   pituitary  0.910320   0.878947     0.948864     0.881789  0.912568
# 4      2      glioma  0.923132   0.949495     0.870370     0.886792  0.908213
# 5      2  meningioma  0.923132   0.849850     0.860182     0.886792  0.854985
# 6      2     notumor  0.923132   0.980198     0.990000     0.886792  0.985075
# 7      2   pituitary  0.923132   0.905660     0.954545     0.886792  0.929461
# 8      3      glioma  0.913879   0.972028     0.855385     0.876972  0.909984
# 9      3  meningioma  0.913879   0.837278     0.860182     0.876972  0.848576
# 10     3     notumor  0.913879   0.984694     0.965000     0.876972  0.974747
# 11     3   pituitary  0.913879   0.866324     0.960114     0.876972  0.910811
# 12     4      glioma  0.920228   0.875362     0.932099     0.943750  0.902840
# 13     4  meningioma  0.920228   0.878594     0.835866     0.943750  0.856698
# 14     4     notumor  0.920228   0.979540     0.957500     0.943750  0.968394
# 15     4   pituitary  0.920228   0.935211     0.945869     0.943750  0.940510
# 16     5      glioma  0.915954   0.848739     0.935185     0.949843  0.889868
# 17     5  meningioma  0.915954   0.894915     0.802432     0.949843  0.846154
# 18     5     notumor  0.915954   0.977387     0.972500     0.949843  0.974937
# 19     5   pituitary  0.915954   0.932203     0.940171     0.949843  0.936170
#
#     time_taken
# 0    64.093850
# 1    64.093850
# 2    64.093850
# 3    64.093850
# 4    51.698266
# 5    51.698266
# 6    51.698266
# 7    51.698266
# 8    65.487791
# 9    65.487791
# 10   65.487791
# 11   65.487791
# 12   44.032128
# 13   44.032128
# 14   44.032128
# 15   44.032128
# 16   47.939479
# 17   47.939479
# 18   47.939479
# 19   47.939479

# %%
df_results_class_fine
# Out:
#         class  accuracy  precision  sensitivity  specificity  f1-score  \
# 0      glioma  0.996441   0.996923     1.000000          1.0  0.998459
# 1  meningioma  0.996441   0.996933     0.987842          1.0  0.992366
# 2     notumor  0.996441   0.997506     1.000000          1.0  0.998752
# 3   pituitary  0.996441   0.994334     0.997159          1.0  0.995745
#
#    time_taken
# 0  115.375841
# 1  115.375841
# 2  115.375841
# 3  115.375841

# %% [markdown]
# # PREDICT

# %%
# Load the trained model
model = tf.keras.models.load_model('model_InceptionResNetV2_final.h5')

# Define the classes
classes = ['glioma', 'meningioma', 'notumor','pituitary']

# Preprocess the input data
def preprocess_input(img):
    # Resize the input image to match the model's input size
    img = cv2.resize(img, (299, 299))
    # Convert the input image to a float32 array and normalize its pixel values
    img = img.astype(np.float32) / 255.0
    # Add an extra dimension to the input to match the model's input shape
    img = np.expand_dims(img, axis=0)
    return img

# Load the input image
# img_path = '/content/dataset-testing-proccess/no_tumor/image(1)_cropped_0.jpg'
img_path = '/content/Brain Tumor Dataset-proccess/glioma/Te-glTr_0000_cropped_0.jpg'
img = cv2.imread(img_path)

# Preprocess the input image
img = preprocess_input(img)

# Predict the class probabilities for the input image
probs = model.predict(img)[0]

# Convert the probabilities to a predicted class label
predicted_class = classes[np.argmax(probs)]

# Print the predicted class label and probabilities for all classes
print('Predicted class:', predicted_class)
print('Class probabilities:', dict(zip(classes, probs)))
# Out:
# WARNING:tensorflow:6 out of the last 27 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fedec521870> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 3s 3s/step
# Predicted class: glioma
# Class probabilities: {'glioma': 0.997988, 'meningioma': 0.0012119953, 'notumor': 0.00067879964, 'pituitary': 0.000121301564}

# %%
import numpy as np
import cv2
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
from google.colab.patches import cv2_imshow

# Load the saved model
model = load_model('model_InceptionResNetV2_final.h5')

# Load the image and preprocess it
# img_path = '/content/dataset-testing-proccess/no_tumor/image(1)_cropped_0.jpg'
img_path = '/content/Brain Tumor Dataset/glioma/Te-glTr_0000.jpg'
img = image.load_img(img_path, target_size=(299, 299))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = x / 255.

# Predict the segmentation mask for the image
pred_mask = model.predict(x)[0]
pred_mask = np.argmax(pred_mask, axis=-1)
pred_mask = np.expand_dims(pred_mask, axis=-1)

# Resize the mask to the original image size
orig_img = cv2.imread(img_path)
mask = cv2.resize(pred_mask, (orig_img.shape[1], orig_img.shape[0]), interpolation=cv2.INTER_NEAREST)
mask = np.squeeze(mask)

# Threshold the mask to get the tumor region
threshold = 0.5
mask = np.where(mask > threshold, 1, 0)

# Find the contours of the tumor region
contours, _ = cv2.findContours(mask.astype(np.uint8), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Draw the contours on the original image
output_img = orig_img.copy()
for cnt in contours:
    cv2.drawContours(output_img, [cnt], 0, (0, 255, 0), 2)

# Display the output image with contours
cv2_imshow(output_img)
cv2.waitKey(0)
# Out:
# WARNING:tensorflow:5 out of the last 26 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fee0826b400> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 3s 3s/step
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FEE08C629B0>
# -1

# %% [markdown]
# ## The Xception model development and fine tuning
#
# in this notebook we will load and add our layers to the base model of the pre-trained Xception model, and fine tune the following parameters of the model:
#
# # **Setting up the Environment**

# %%
# Delete All Folder
# import shutil
# shutil.rmtree('/content/Brain Tumor Dataset')
# shutil.rmtree('/content/Brain Tumor Dataset-cropped')
# shutil.rmtree('/content/Brain Tumor Dataset-proccess')
# shutil.rmtree('/content/dataset-testing')
# shutil.rmtree('/content/dataset-testing-cropped')
# shutil.rmtree('/content/dataset-testing-proccess')
# # shutil.rmtree('/content/preview')

# %%
import pandas as pd
import numpy as np
import os
import tensorflow as tf
import keras
import matplotlib.pyplot as plt
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.applications import Xception
from tensorflow.keras.preprocessing import image
# from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Input
from sklearn.metrics import confusion_matrix
from tensorflow.keras.applications import Xception
from tqdm import tqdm_notebook
import time
# import tqdm.gui as tqdm
# import tqdm.notebook as tqdm
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report
from tqdm import tqdm
import pickle

import glob
import random
from matplotlib.image import imread
import cv2
import imutils
from pathlib import Path
from tensorflow.keras.applications.xception import preprocess_input
from keras.metrics import Precision, Recall, AUC
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import seaborn as sns

from tensorflow.keras.layers import Activation, Dense
from tabulate import tabulate
from sklearn.model_selection import StratifiedKFold
from pylab import rcParams

# %%
#Menghubungkan ke google drive

from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# Mengambil dataset dari google drive

import zipfile  # library untuk mempercepat extract file
dataset_path = "/gdrive/My Drive/SKRIPSI/Dataset/Brain Tumor Dataset.zip"
# dataset_path = "/gdrive/My Drive/SKRIPSI/Dataset/dataset-testing.zip"
zfile = zipfile.ZipFile(dataset_path)
zfile.extractall()

# %%
# Konstanta
IMG_PATH = '/content/Brain Tumor Dataset/'
# IMG_PATH= '/content/dataset-testing'
CROPPED_IMG_PATH = '/content/Brain Tumor Dataset-cropped'
# CROPPED_IMG_PATH = '/content/dataset-testing-cropped'
PROCCESS_IMG_PATH = '/content/Brain Tumor Dataset-proccess'
# PROCCESS_IMG_PATH = '/content/dataset-testing-proccess'
RESULT_FOLDER = '/gdrive/My Drive/SKRIPSI/Result/Xception_coba3/'
IMG_SIZE = 299, 299

# %% [markdown]
# # **Common functions**

# %%
# common functions that i will use

def get_data_generator(train_data_path, \
                       val_data_path, \
                       targetsize, \
                       classmode, \
                       batchsize):
    """
    This function is a data generator function for train, validation, and testing data
    Inputs
        train_data_path   : train data path for the dataset 
        val_data_path     : validation data path for the dataset
        targetsize        : target size for the generator to resize all images to, (224,224)
        classmode         : class mode, 'categorical'
        batchsize         : batch size
    Outputs
        train_generator   : generated train data
        val_generator     : generated validation data
    
    """
    train_datagen=ImageDataGenerator(preprocessing_function=preprocess_input)
    val_datagen = ImageDataGenerator(preprocessing_function=preprocess_input)
    
    
    train_generator=train_datagen.flow_from_directory(train_data_path, # this is where you specify the path to the main data folder
                                                 target_size=targetsize,
                                                 color_mode='rgb',
                                                 batch_size=batchsize,
                                                 class_mode=classmode,
                                                 shuffle=True)
    
    val_generator=val_datagen.flow_from_directory(val_data_path, # this is where you specify the path to the main data folder
                                                 target_size=targetsize,
                                                 color_mode='rgb',
                                                 batch_size=batchsize,
                                                 class_mode=classmode)
 
    return train_generator,val_generator

# %%
def train_evaluate_the_model(train_generator, val_generator, optimizer, epochs, dropout_value, TheModel):
    '''
    train the model, do predictions, and do evaluation and return the accuracy, precision, recall, and f1-score of the model
    Inputs
        train_generator : generated train data
        val_generator   : generated validation data
        optimizer       : the optimizer method used to compile the model
        epochs          : the epochs of the model use to fit the model
        dropout_value   : the dropout value
        TheModel        : The pretrained model loaded,
    Outputs
        accuracy        : The accuracy of the model
        precision       : The precision of the model
        recall          : The recall of the model
        f1_score        : The f1_score of the model
    '''

    # freeze base layers for training
    for layer in TheModel.layers:
        layer.trainable = False

    # load pretrained model and add layers on top of the model
    x = TheModel.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(512, activation='relu', kernel_regularizer=l1_l2(l1=1e-5, l2=1e-4))(x)
    x = BatchNormalization()(x)
    x = tf.keras.layers.Dropout(dropout_value)(x)
    x = Dense(256, activation='relu', kernel_regularizer=l1_l2(l1=1e-5, l2=1e-4))(x)
    x = BatchNormalization()(x)
    x = tf.keras.layers.Dropout(dropout_value)(x)
    predictions = Dense(4, activation="softmax")(x)
    model = Model(inputs = TheModel.input, outputs = predictions)

    # compile the model
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

    # fit the model

    tic = time.time()
    # Train model 
    step_size_train = train_generator.n//train_generator.batch_size
    r = model.fit(train_generator,
                            validation_data=val_generator,
                            steps_per_epoch=step_size_train,
                            epochs=epochs,callbacks=[early_stop])
    toc = time.time()

    predictions = model.predict(val_generator)
    y_true = val_generator.labels
    y_pred = np.argmax(predictions, axis=1)

     # hitung confusion matrix dan hasil evaluasi per kelas
    cm = confusion_matrix(y_true, y_pred)
    class_names = train_generator.class_indices.keys()
    report = classification_report(y_true, y_pred, target_names=class_names, output_dict=True)

     # hitung specificity 
    tn, fp, fn, tp = cm[0][0], cm[0][1], cm[1][0], cm[1][1]
    specificity = []
    for i in range(len(class_names)):
        spec = tn / (tn + fp)
        specificity.append(spec)
    
    # tampilkan confusion matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.title(f'Confusion Matrix')
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.show()

    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='macro')
    sensitivity_ava = recall_score(y_true, y_pred, average='macro')
    f1 = f1_score(y_true, y_pred, average='macro')
    time_taken = toc - tic

    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']

    loss = history.history['loss']
    val_loss = history.history['val_loss']

    plt.figure(figsize=(8, 8))
    plt.subplot(2, 1, 1)
    plt.plot(acc, label='Training Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.ylabel('Accuracy')
    plt.ylim([min(plt.ylim()),1])
    plt.title(f'Training and Validation Accuracy Xception')

    plt.subplot(2, 1, 2)
    plt.plot(loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.ylabel('Cross Entropy')
    plt.ylim([0,1.0])
    plt.title(f'Training and Validation Loss Xception')
    plt.xlabel('epoch')
    plt.show()

    return accuracy, precision, sensitivity_ava,np.mean(specificity), f1, time_taken/60.0, model

# %%
def crop_imgs(set_name, add_pixels_value=0):
    """
    Finds the extreme points on the image and crops the rectangular out of them
    """
    set_new = []
    for img in set_name:
        gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
        gray = cv2.GaussianBlur(gray, (5, 5), 0)

        # threshold the image, then perform a series of erosions +
        # dilations to remove any small regions of noise
        thresh = cv2.threshold(gray, 45, 255, cv2.THRESH_BINARY)[1]
        thresh = cv2.erode(thresh, None, iterations=2)
        thresh = cv2.dilate(thresh, None, iterations=2)

        # find contours in thresholded image, then grab the largest one
        cnts = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        cnts = imutils.grab_contours(cnts)
        c = max(cnts, key=cv2.contourArea)

        # find the extreme points
        extLeft = tuple(c[c[:, :, 0].argmin()][0])
        extRight = tuple(c[c[:, :, 0].argmax()][0])
        extTop = tuple(c[c[:, :, 1].argmin()][0])
        extBot = tuple(c[c[:, :, 1].argmax()][0])

        ADD_PIXELS = add_pixels_value
        new_img = img[extTop[1]-ADD_PIXELS:extBot[1]+ADD_PIXELS, extLeft[0]-ADD_PIXELS:extRight[0]+ADD_PIXELS].copy()
        set_new.append(new_img)

    return np.array(set_new)

# %%
def create_folder(folder_path):
    """
    Create a new folder at the specified path.
    :param folder_path: Path to the new folder
    :type folder_path: str
    """
    try:
        os.mkdir(folder_path)
        print(f"Folder '{folder_path}' created successfully.")
    except FileExistsError:
        print(f"Folder '{folder_path}' already exists.")

# %%
def plot_sample(class_names, img_dir, num_samples=10):
    """
    Plot sample images from each label in class_names
    :param class_names: List of class names
    :param img_dir: Path to directory containing image files
    :param num_samples: Number of images to plot per label
    """
    # create dictionary of class indices
    class_indices = {class_names[i]: i for i in range(len(class_names))}

    # create subplot for each class
    fig, axes = plt.subplots(nrows=len(class_names), ncols=num_samples, figsize=(12, 12))

    # plot each image for each class
    for i, label in enumerate(class_names):
        # path to directory for current label
        label_dir = os.path.join(img_dir, label)
        # list of file names in current directory
        file_names = os.listdir(label_dir)
        # select random samples from list
        samples = random.sample(file_names, num_samples)
        for j, sample in enumerate(samples):
            # path to current image file
            img_path = os.path.join(label_dir, sample)
            # read image file
            img = imread(img_path)
            # plot image
            axes[i, j].imshow(img)
            axes[i, j].axis("off")
            if j == num_samples // 2:
                axes[i, j].set_title(label, y=1.2)
    plt.show()

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure(figsize = (6,6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    cm = np.round(cm,2)
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.show()

# %%
def apply_crop(IMG_PATH_BEFORE,IMG_PATH_AFTER): 
  before = os.listdir(IMG_PATH_BEFORE)
  after = os.listdir(IMG_PATH_AFTER)

  # apply this for each set
  for folder in before:
      folder_path = os.path.join(IMG_PATH_BEFORE, folder)
      if os.path.isdir(folder_path):
          output_folder_path = os.path.join(IMG_PATH_AFTER, folder)
          Path(output_folder_path).mkdir(parents=True, exist_ok=True) # create the output folder if it does not exist
          for file_name in os.listdir(folder_path):
              if file_name.endswith(".jpg"): # assuming that the images are in JPG format
                  file_path = os.path.join(folder_path, file_name)
                  img = cv2.imread(file_path)
                  cropped_imgs = crop_imgs([img])
                  for i, cropped_img in enumerate(cropped_imgs):
                      output_file_path = os.path.join(output_folder_path, f"{file_name[:-4]}_cropped_{i}.jpg") # assuming that you want to append _cropped_0, _cropped_1, etc. to the original file name
                      cv2.imwrite(output_file_path, cropped_img)

# %%
def apply_preprocessing(IMG_PATH_BEFORE, IMG_PATH_AFTER, img_size=(299,299)):
    """
    Resize and apply Xception preprocessing and save the images to output_dir
    """
    # create output_dir if it does not exist
    os.makedirs(IMG_PATH_AFTER, exist_ok=True)
    
    for class_name in os.listdir(IMG_PATH_BEFORE):
        class_dir = os.path.join(IMG_PATH_BEFORE, class_name)
        for img_path in os.listdir(class_dir):
            img_path = os.path.join(class_dir, img_path)
            # Load image from file path
            img = cv2.imread(img_path)
            # Resize image
            img = cv2.resize(
                img,
                dsize=img_size,
                interpolation=cv2.INTER_CUBIC
            )
            # Save the preprocessed image
            output_path = os.path.join(IMG_PATH_AFTER, class_name, os.path.basename(img_path))
            os.makedirs(os.path.dirname(output_path), exist_ok=True)
            cv2.imwrite(output_path, img)

# %%
def plot_results(x_axis, x_label,y_axis, y_label):
    rcParams['figure.figsize'] = 10,8 # width 10, height 8
    ax = result_table.plot(x=x_axis, y=y_axis, style='bx-', grid=True)
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)

# %%
def upload_drive(FILE_PATH,TARGET_FOLDER):
  # path file yang akan diupload
  file_path = '/content/'+FILE_PATH

  # folder tujuan di Google Drive
  target_folder = TARGET_FOLDER

  # nama file setelah diupload
  file_name = os.path.basename(file_path)

  # copy file ke Google Drive
  # !cp "{file_path}" "{target_folder}/{file_name}"
  print(f'File {file_name} berhasil diupload ke folder {target_folder}')

# %%
def create_optimizer(optimizer, learning_rate=1e-4):
    if optimizer == 'Adam':
        return tf.keras.optimizers.Adam(learning_rate=learning_rate)
    elif optimizer == 'Adamax':
        return tf.keras.optimizers.Adamax(learning_rate=learning_rate)
    elif optimizer == 'Nadam':
        return tf.keras.optimizers.Nadam(learning_rate=learning_rate)
    else:
        raise ValueError('Invalid optimizer :',optimizer)

# %%
from tensorflow.keras.callbacks import EarlyStopping

# Create an early stopping callback
early_stop = EarlyStopping(monitor='val_loss', patience=5)

# %% [markdown]
# # **Data import and Preprocessing**

# %%
# Ambil nama folder yang berisi data
label = os.listdir(IMG_PATH)

# %%
class_indices = {label[i]: i for i in range(len(label))}

print("Label Class : ",class_indices," \n")

# Loop melalui setiap folder dan ambil nama file
sum = 0
for label_name in label:
    file_names = glob.glob(os.path.join(IMG_PATH, label_name, '*'))
    num_files = len(file_names)
    sum += num_files
    print(f'{label_name}: {num_files} images')
print()
print("Total: ", sum, " images")
# Out:
# Label Class :  {'pituitary': 0, 'meningioma': 1, 'notumor': 2, 'glioma': 3}
#
# pituitary: 1757 images
# meningioma: 1645 images
# notumor: 2000 images
# glioma: 1621 images
#
# Total:  7023  images

# %%
plot_sample(label,IMG_PATH,10)

# %% [markdown]
# **CROPPING IMAGES**

# %%
img = cv2.imread('/content/Brain Tumor Dataset/glioma/Te-glTr_0000.jpg')
# img = cv2.imread('/content/dataset-testing/glioma_tumor/image(1).jpg')
img = cv2.resize(
            img,
            dsize=IMG_SIZE,
            interpolation=cv2.INTER_CUBIC
        )
gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
gray = cv2.GaussianBlur(gray, (5, 5), 0)

# threshold the image, then perform a series of erosions +
# dilations to remove any small regions of noise
thresh = cv2.threshold(gray, 45, 255, cv2.THRESH_BINARY)[1]
thresh = cv2.erode(thresh, None, iterations=2)
thresh = cv2.dilate(thresh, None, iterations=2)

# find contours in thresholded image, then grab the largest one
cnts = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
cnts = imutils.grab_contours(cnts)
c = max(cnts, key=cv2.contourArea)

# find the extreme points
extLeft = tuple(c[c[:, :, 0].argmin()][0])
extRight = tuple(c[c[:, :, 0].argmax()][0])
extTop = tuple(c[c[:, :, 1].argmin()][0])
extBot = tuple(c[c[:, :, 1].argmax()][0])

# add contour on the image
img_cnt = cv2.drawContours(img.copy(), [c], -1, (0, 255, 255), 4)

# add extreme points
img_pnt = cv2.circle(img_cnt.copy(), extLeft, 8, (0, 0, 255), -1)
img_pnt = cv2.circle(img_pnt, extRight, 8, (0, 255, 0), -1)
img_pnt = cv2.circle(img_pnt, extTop, 8, (255, 0, 0), -1)
img_pnt = cv2.circle(img_pnt, extBot, 8, (255, 255, 0), -1)

# crop
ADD_PIXELS = 0
new_img = img[extTop[1]-ADD_PIXELS:extBot[1]+ADD_PIXELS, extLeft[0]-ADD_PIXELS:extRight[0]+ADD_PIXELS].copy()

# %%
plt.figure(figsize=(15,6))
plt.subplot(141)
plt.imshow(img)
plt.xticks([])
plt.yticks([])
plt.title('Step 1. Get the original image')
plt.subplot(142)
plt.imshow(img_cnt)
plt.xticks([])
plt.yticks([])
plt.title('Step 2. Find the biggest contour')
plt.subplot(143)
plt.imshow(img_pnt)
plt.xticks([])
plt.yticks([])
plt.title('Step 3. Find the extreme points')
plt.subplot(144)
plt.imshow(new_img)
plt.xticks([])
plt.yticks([])
plt.title('Step 4. Crop the image')
plt.show()

# %%
create_folder(CROPPED_IMG_PATH)
# Out:
# Folder '/content/Brain Tumor Dataset-cropped' created successfully.

# %%
apply_crop(IMG_PATH,CROPPED_IMG_PATH)

# %%
plot_sample(label,CROPPED_IMG_PATH,10)

# %%
create_folder(PROCCESS_IMG_PATH)
# Out:
# Folder '/content/Brain Tumor Dataset-proccess' created successfully.

# %%
apply_preprocessing(CROPPED_IMG_PATH,PROCCESS_IMG_PATH,IMG_SIZE)

# %%
plot_sample(label,PROCCESS_IMG_PATH,10)

# %% [markdown]
# **Augmentasi Data**

# %%
demo_datagen = ImageDataGenerator(
    rescale=1./255, 
    rotation_range=20, 
    shear_range=0.2, 
    zoom_range=0.2, 
    horizontal_flip=True, 
    vertical_flip=True, 
    fill_mode='nearest')

# %%
os.mkdir('preview')
x = cv2.imread('/content/Brain Tumor Dataset-proccess/glioma/Te-glTr_0000_cropped_0.jpg')  
# x = cv2.imread('/content/dataset-testing/glioma_tumor/image(1).jpg')  
x = np.expand_dims(x, axis=0)

i = 0
for batch in demo_datagen.flow(x, batch_size=1, save_to_dir='preview', save_prefix='aug_img', save_format='jpg'):
    i += 1
    if i > 20:
        break

# %%
plt.imshow(cv2.imread('/content/Brain Tumor Dataset-proccess/glioma/Te-glTr_0000_cropped_0.jpg')  )
# plt.imshow(cv2.imread('/content/dataset-testing/glioma_tumor/image(1).jpg')  )

plt.xticks([])
plt.yticks([])
plt.title('Original Image')
plt.show()

plt.figure(figsize=(15,6))
i = 1
for img in os.listdir('preview/'):
    img = cv2.imread('preview/' + img)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    plt.subplot(3,7,i)
    plt.imshow(img)
    plt.xticks([])
    plt.yticks([])
    i += 1
    if i > 3*7:
        break
plt.suptitle('Augemented Images')
plt.show()

# %%
# !rm -rf preview/

# %% [markdown]
# # **Train Initial**

# %%
# initial parameters
batchsize_initial = 64
epochs_initial = 50
dropout_value_initial = 0.2
optimizer_initial = 'Adam'
num_folds = 5

# tetsing
# batchsize_initial = 1
# epochs_initial = 1
# dropout_value_initial = 0.0
# optimizer_initial = 'Adam'
# num_folds = 2 


# constant parameters
targetsize_constant = (IMG_SIZE)
classmode_constant = 'categorical'

# %%
# Buat list path gambar dan label pada dataset
image_paths = []
image_labels = []
for label_dir in os.listdir(PROCCESS_IMG_PATH):
    label = label_dir.lower()
    label_path = os.path.join(PROCCESS_IMG_PATH, label_dir)
    for image_file in os.listdir(label_path):
        image_path = os.path.join(label_path, image_file)
        image_paths.append(image_path)
        image_labels.append(label)


# # Tampilkan label sebelum di encode
# print("Label sebelum di encode: ", set(image_labels))

# # Ubah label menjadi integer
# le = LabelEncoder()
# image_labels_encoded = le.fit_transform(image_labels)

# # Tampilkan label setelah di encode
# print("Label setelah di encode: ", set(image_labels_encoded))

# # Ubah label menjadi array satu dimensi
# image_labels = np.ravel(image_labels)

# Buat dataframe berisi path gambar dan label
df = pd.DataFrame({'path': image_paths, 'label': image_labels})

# Ubah tipe data kolom "label" menjadi string
df['label'] = df['label'].astype(str)

# Buat data generator
datagen = ImageDataGenerator(
    rescale=1./255, 
    rotation_range=20, 
    shear_range=0.2, 
    zoom_range=0.2, 
    horizontal_flip=True, 
    vertical_flip=True, 
    fill_mode='nearest')
# Lakukan cross validation
skf = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=42)

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
from tensorflow.keras.regularizers import l1_l2

# %%
results = []
results_class = []
best_sensitivity = 0
best_fold = 0

for fold, (train_index, val_index) in enumerate(skf.split(df['path'], df['label'])):
    train_df = df.iloc[train_index]
    val_df = df.iloc[val_index]

    # simpan train_df dan val_df di setiap foldnya
    with open(f'train_df_fold{fold+1}.pkl', 'wb') as f:
        pickle.dump(train_df, f)
    with open(f'val_df_fold{fold+1}.pkl', 'wb') as f:
        pickle.dump(val_df, f)
    
    upload_drive(f'train_df_fold{fold+1}.pkl',RESULT_FOLDER)
    upload_drive(f'val_df_fold{fold+1}.pkl',RESULT_FOLDER)


    image_size = [299,299] # choose image size

    train_generator_initial = datagen.flow_from_dataframe(dataframe=train_df,
                                                           x_col='path',
                                                           y_col='label',
                                                           color_mode='rgb',
                                                           batch_size=batchsize_initial,
                                                           class_mode="categorical",
                                                           shuffle=True)
    val_generator_initial = datagen.flow_from_dataframe(dataframe=val_df,
                                                         x_col='path',
                                                         y_col='label',
                                                         color_mode='rgb',
                                                         batch_size=batchsize_initial,
                                                         class_mode="categorical",
                                                         shuffle=True)

    # import the base model
    xception_basemodel = Xception(input_shape= image_size+[3],weights='imagenet',include_top=False)

    # storing the base model in the kernel for later use to avoid loading many times
    base_model = xception_basemodel

    # Freeze layer pada model
    for layer in base_model.layers:
        layer.trainable = False

    # Tambahkan layer klasifikasi pada model
    # add layers
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(512, activation='relu', kernel_regularizer=l1_l2(l1=1e-5, l2=1e-4))(x)
    x = BatchNormalization()(x)
    x = tf.keras.layers.Dropout(dropout_value_initial)(x)
    x = Dense(256, activation='relu', kernel_regularizer=l1_l2(l1=1e-5, l2=1e-4))(x)
    x = BatchNormalization()(x)
    x = tf.keras.layers.Dropout(dropout_value_initial)(x)
    predictions = Dense(4, activation="softmax")(x)
    model = Model(inputs = base_model.input, outputs = predictions)

    optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)
    # compile the model
    model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

    tic = time.time()
    # Train model pada setiap fold
    step_size_train_initial=train_generator_initial.n//train_generator_initial.batch_size
    history = model.fit(train_generator_initial, epochs=epochs_initial,steps_per_epoch=step_size_train_initial, validation_data=val_generator_initial,callbacks=[early_stop])

    toc = time.time()

    # Evaluasi model pada validasi set
    val_generator = datagen.flow_from_dataframe(dataframe=val_df,
                                                x_col='path',
                                                y_col='label',
                                                color_mode='rgb',
                                                batch_size=batchsize_initial,
                                                class_mode="categorical",
                                                shuffle=False)
    # evaluation on validation data
    scores = model.evaluate(val_generator)
    print("%s%s: %.2f%%" % ("evaluate ",model.metrics_names[1], scores[1]*100))

    predictions = model.predict(val_generator)
    y_true = val_generator.labels
    y_pred = np.argmax(predictions, axis=1)

    # hitung confusion matrix dan hasil evaluasi per kelas
    cm = confusion_matrix(y_true, y_pred)
    class_names = train_generator_initial.class_indices.keys()
    report = classification_report(y_true, y_pred, target_names=class_names, output_dict=True)

     # hitung specificity 
    tn, fp, fn, tp = cm[0][0], cm[0][1], cm[1][0], cm[1][1]
    specificity = []
    for i in range(len(class_names)):
        spec = tn / (tn + fp)
        specificity.append(spec)

    # tampilkan confusion matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
    plt.title(f'Confusion Matrix (Fold {fold+1})')
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.show()

    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='macro')
    sensitivity_ava = recall_score(y_true, y_pred, average='macro')
    f1 = f1_score(y_true, y_pred, average='macro')
    time_taken = toc - tic

    if fold == 0:
      best_sensitivity = sensitivity_ava
      best_fold = fold+1
    elif best_sensitivity < sensitivity_ava:
      best_sensitivity = sensitivity_ava
      best_fold = fold+1

    # tampilkan hasil evaluasi per kelas
    for i, name in enumerate(class_names):
        results_class.append({'fold': fold+1, 'class': name,'accuracy': accuracy,'precision': report[name]['precision'],
                                  'sensitivity': report[name]['recall'], 'specificity': specificity[i],
                                   'f1-score': report[name]['f1-score'], 'time_taken': time_taken/60.0})

    results.append({'fold':fold+1,
                'accuracy': accuracy,
                'precision': precision,
                'sensitivity': sensitivity_ava,
                'specificity': np.mean(specificity),  # menambahkan rata-rata specificity untuk setiap kelas
                'f1-score': f1,
                'time_taken': time_taken/60.0})

    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']

    loss = history.history['loss']
    val_loss = history.history['val_loss']

    plt.figure(figsize=(8, 8))
    plt.subplot(2, 1, 1)
    plt.plot(acc, label='Training Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.legend(loc='lower right')
    plt.ylabel('Accuracy')
    plt.ylim([min(plt.ylim()),1])
    plt.title(f'Training and Validation Accuracy Xception (Fold {fold+1})')

    plt.subplot(2, 1, 2)
    plt.plot(loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.legend(loc='upper right')
    plt.ylabel('Cross Entropy')
    plt.ylim([0,1.0])
    plt.title(f'Training and Validation Loss Xception (Fold {fold+1})')
    plt.xlabel('epoch')
    plt.show()

    model.save(f'fold_{fold+1}_model.h5')
    upload_drive(f'fold_{fold+1}_model.h5',RESULT_FOLDER)

# Konversi list results ke dalam dataframe pandas
df_results = pd.DataFrame(results, columns=['fold', 'accuracy','precision', 'sensitivity','specificity', 'f1-score', 'time_taken'])
df_results_class = pd.DataFrame(results_class, columns=['fold', 'class','accuracy', 'precision','sensitivity', 'specificity', 'f1-score', 'time_taken'])
# Tampilkan hasil evaluasi dalam bentuk tabel
pd.DataFrame(df_results)
pd.DataFrame(df_results_class)
print('Best Fold:',best_fold)
print('Best Sensitivity:',best_sensitivity)
# Out:
# File train_df_fold1.pkl berhasil diupload ke folder /gdrive/My Drive/SKRIPSI/Result/Xception_coba3/
# File val_df_fold1.pkl berhasil diupload ke folder /gdrive/My Drive/SKRIPSI/Result/Xception_coba3/
# Found 5618 validated image filenames belonging to 4 classes.
# Found 1405 validated image filenames belonging to 4 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 [==============================] - 5s 0us/step
# Epoch 1/50
# 87/87 [==============================] - 124s 1s/step - loss: 1.3249 - accuracy: 0.6743 - val_loss: 1.3156 - val_accuracy: 0.6989
# Epoch 2/50
# 87/87 [==============================] - 103s 1s/step - loss: 1.0010 - accuracy: 0.7863 - val_loss: 1.0617 - val_accuracy: 0.7815
# Epoch 3/50
# 87/87 [==============================] - 103s 1s/step - loss: 0.9291 - accuracy: 0.8120 - val_loss: 0.8868 - val_accuracy: 0.8406
# Epoch 4/50
# 87/87 [==============================] - 104s 1s/step - loss: 0.8718 - accuracy: 0.8353 - val_loss: 0.8024 - val_accuracy: 0.8655
# Epoch 5/50
# 87/87 [==============================] - 104s 1s/step - loss: 0.8289 - accuracy: 0.8502 - val_loss: 0.7947 - val_accuracy: 0.8754
# Epoch 6/50
# 87/87 [==============================] - 102s 1s/step - loss: 0.8002 - accuracy: 0.8599 - val_loss: 0.7555 - val_accuracy: 0.8762
# Epoch 7/50
# 87/87 [==============================] - 103s 1s/step - loss: 0.7816 - accuracy: 0.8646 - val_loss: 0.7697 - val_accuracy: 0.8769
# Epoch 8/50
# 87/87 [==============================] - 105s 1s/step - loss: 0.7681 - accuracy: 0.8693 - val_loss: 0.7537 - val_accuracy: 0.8783
# Epoch 9/50
# 87/87 [==============================] - 103s 1s/step - loss: 0.7326 - accuracy: 0.8803 - val_loss: 0.7731 - val_accuracy: 0.8762
# Epoch 10/50
# 87/87 [==============================] - 103s 1s/step - loss: 0.7314 - accuracy: 0.8806 - val_loss: 0.6998 - val_accuracy: 0.9046
# Epoch 11/50
# 87/87 [==============================] - 103s 1s/step - loss: 0.7173 - accuracy: 0.8920 - val_loss: 0.7397 - val_accuracy: 0.8854
# Epoch 12/50
# 87/87 [==============================] - 103s 1s/step - loss: 0.7061 - accuracy: 0.8918 - val_loss: 0.6778 - val_accuracy: 0.9039
# Epoch 13/50
# 87/87 [==============================] - 103s 1s/step - loss: 0.7162 - accuracy: 0.8902 - val_loss: 0.6748 - val_accuracy: 0.9125
# Epoch 14/50
# 87/87 [==============================] - 102s 1s/step - loss: 0.7063 - accuracy: 0.8923 - val_loss: 0.7165 - val_accuracy: 0.8932
# Epoch 15/50
# 87/87 [==============================] - 102s 1s/step - loss: 0.6965 - accuracy: 0.8950 - val_loss: 0.6877 - val_accuracy: 0.8989
# Epoch 16/50
# 87/87 [==============================] - 104s 1s/step - loss: 0.6777 - accuracy: 0.9003 - val_loss: 0.6947 - val_accuracy: 0.9018
# Epoch 17/50
# 87/87 [==============================] - 103s 1s/step - loss: 0.6706 - accuracy: 0.9033 - val_loss: 0.6689 - val_accuracy: 0.9053
# Epoch 18/50
# 87/87 [==============================] - 103s 1s/step - loss: 0.6752 - accuracy: 0.9017 - val_loss: 0.6484 - val_accuracy: 0.9139
# Epoch 19/50
# 87/87 [==============================] - 103s 1s/step - loss: 0.6682 - accuracy: 0.9015 - val_loss: 0.6709 - val_accuracy: 0.8996
# Epoch 20/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.6519 - accuracy: 0.9082 - val_loss: 0.6437 - val_accuracy: 0.9125
# Epoch 21/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.6351 - accuracy: 0.9156 - val_loss: 0.6554 - val_accuracy: 0.9053
# Epoch 22/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.6381 - accuracy: 0.9130 - val_loss: 0.6526 - val_accuracy: 0.9132
# Epoch 23/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.6210 - accuracy: 0.9190 - val_loss: 0.6536 - val_accuracy: 0.9075
# Epoch 24/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.6220 - accuracy: 0.9183 - val_loss: 0.6182 - val_accuracy: 0.9231
# Epoch 25/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.6310 - accuracy: 0.9132 - val_loss: 0.6452 - val_accuracy: 0.9181
# Epoch 26/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.6150 - accuracy: 0.9186 - val_loss: 0.6196 - val_accuracy: 0.9203
# Epoch 27/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.6102 - accuracy: 0.9228 - val_loss: 0.6201 - val_accuracy: 0.9224
# Epoch 28/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.6009 - accuracy: 0.9237 - val_loss: 0.6267 - val_accuracy: 0.9181
# Epoch 29/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.6052 - accuracy: 0.9210 - val_loss: 0.6228 - val_accuracy: 0.9167
# Found 1405 validated image filenames belonging to 4 classes.
# 22/22 [==============================] - 20s 912ms/step - loss: 0.6154 - accuracy: 0.9210
# evaluate accuracy: 92.10%
# 22/22 [==============================] - 20s 897ms/step
# File fold_1_model.h5 berhasil diupload ke folder /gdrive/My Drive/SKRIPSI/Result/Xception_coba3/
# File train_df_fold2.pkl berhasil diupload ke folder /gdrive/My Drive/SKRIPSI/Result/Xception_coba3/
# File val_df_fold2.pkl berhasil diupload ke folder /gdrive/My Drive/SKRIPSI/Result/Xception_coba3/
# Found 5618 validated image filenames belonging to 4 classes.
# Found 1405 validated image filenames belonging to 4 classes.
# Epoch 1/50
# 87/87 [==============================] - 106s 1s/step - loss: 1.2641 - accuracy: 0.6921 - val_loss: 1.3119 - val_accuracy: 0.7317
# Epoch 2/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.9947 - accuracy: 0.7847 - val_loss: 1.0543 - val_accuracy: 0.7886
# Epoch 3/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.9196 - accuracy: 0.8167 - val_loss: 0.9039 - val_accuracy: 0.8278
# Epoch 4/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.8374 - accuracy: 0.8453 - val_loss: 0.8210 - val_accuracy: 0.8520
# Epoch 5/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.8223 - accuracy: 0.8504 - val_loss: 0.7782 - val_accuracy: 0.8726
# Epoch 6/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.8160 - accuracy: 0.8547 - val_loss: 0.7428 - val_accuracy: 0.8861
# Epoch 7/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.7733 - accuracy: 0.8720 - val_loss: 0.7527 - val_accuracy: 0.8797
# Epoch 8/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.7589 - accuracy: 0.8745 - val_loss: 0.7503 - val_accuracy: 0.8804
# Epoch 9/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.7395 - accuracy: 0.8797 - val_loss: 0.7143 - val_accuracy: 0.8954
# Epoch 10/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.7325 - accuracy: 0.8817 - val_loss: 0.7010 - val_accuracy: 0.8918
# Epoch 11/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.7140 - accuracy: 0.8907 - val_loss: 0.7244 - val_accuracy: 0.8904
# Epoch 12/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.7032 - accuracy: 0.8912 - val_loss: 0.7286 - val_accuracy: 0.8982
# Epoch 13/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.6958 - accuracy: 0.8961 - val_loss: 0.7145 - val_accuracy: 0.8940
# Epoch 14/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.6872 - accuracy: 0.8961 - val_loss: 0.7090 - val_accuracy: 0.9025
# Epoch 15/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.6909 - accuracy: 0.8963 - val_loss: 0.7027 - val_accuracy: 0.8883
# Found 1405 validated image filenames belonging to 4 classes.
# 22/22 [==============================] - 20s 915ms/step - loss: 0.7017 - accuracy: 0.8961
# evaluate accuracy: 89.61%
# 22/22 [==============================] - 20s 895ms/step
# File fold_2_model.h5 berhasil diupload ke folder /gdrive/My Drive/SKRIPSI/Result/Xception_coba3/
# File train_df_fold3.pkl berhasil diupload ke folder /gdrive/My Drive/SKRIPSI/Result/Xception_coba3/
# File val_df_fold3.pkl berhasil diupload ke folder /gdrive/My Drive/SKRIPSI/Result/Xception_coba3/
# Found 5618 validated image filenames belonging to 4 classes.
# Found 1405 validated image filenames belonging to 4 classes.
# Epoch 1/50
# 87/87 [==============================] - 105s 1s/step - loss: 1.3076 - accuracy: 0.6761 - val_loss: 1.2259 - val_accuracy: 0.8043
# Epoch 2/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.9925 - accuracy: 0.7883 - val_loss: 0.9903 - val_accuracy: 0.8477
# Epoch 3/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.9221 - accuracy: 0.8201 - val_loss: 0.8874 - val_accuracy: 0.8391
# Epoch 4/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.8761 - accuracy: 0.8374 - val_loss: 0.7857 - val_accuracy: 0.8754
# Epoch 5/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.8307 - accuracy: 0.8511 - val_loss: 0.7670 - val_accuracy: 0.8676
# Epoch 6/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.8129 - accuracy: 0.8525 - val_loss: 0.7527 - val_accuracy: 0.8754
# Epoch 7/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.7814 - accuracy: 0.8691 - val_loss: 0.7367 - val_accuracy: 0.8904
# Epoch 8/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.7564 - accuracy: 0.8799 - val_loss: 0.7367 - val_accuracy: 0.8811
# Epoch 9/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.7616 - accuracy: 0.8718 - val_loss: 0.7270 - val_accuracy: 0.8904
# Epoch 10/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.7301 - accuracy: 0.8855 - val_loss: 0.7266 - val_accuracy: 0.8904
# Epoch 11/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.7392 - accuracy: 0.8839 - val_loss: 0.7060 - val_accuracy: 0.8996
# Epoch 12/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.7107 - accuracy: 0.8938 - val_loss: 0.7053 - val_accuracy: 0.8904
# Epoch 13/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.7054 - accuracy: 0.8900 - val_loss: 0.6898 - val_accuracy: 0.9004
# Epoch 14/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.6977 - accuracy: 0.8985 - val_loss: 0.6692 - val_accuracy: 0.9117
# Epoch 15/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.6889 - accuracy: 0.8932 - val_loss: 0.6845 - val_accuracy: 0.9053
# Epoch 16/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.6881 - accuracy: 0.8949 - val_loss: 0.6829 - val_accuracy: 0.9025
# Epoch 17/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.6638 - accuracy: 0.9055 - val_loss: 0.6646 - val_accuracy: 0.9125
# Epoch 18/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.6627 - accuracy: 0.9096 - val_loss: 0.6525 - val_accuracy: 0.9146
# Epoch 19/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.6528 - accuracy: 0.9098 - val_loss: 0.6654 - val_accuracy: 0.9004
# Epoch 20/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.6480 - accuracy: 0.9114 - val_loss: 0.6431 - val_accuracy: 0.9139
# Epoch 21/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.6444 - accuracy: 0.9139 - val_loss: 0.6286 - val_accuracy: 0.9210
# Epoch 22/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.6296 - accuracy: 0.9154 - val_loss: 0.6540 - val_accuracy: 0.9046
# Epoch 23/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.6274 - accuracy: 0.9220 - val_loss: 0.6633 - val_accuracy: 0.9082
# Epoch 24/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.6400 - accuracy: 0.9103 - val_loss: 0.6465 - val_accuracy: 0.9210
# Epoch 25/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.6221 - accuracy: 0.9143 - val_loss: 0.6639 - val_accuracy: 0.9153
# Epoch 26/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.6153 - accuracy: 0.9210 - val_loss: 0.6272 - val_accuracy: 0.9181
# Epoch 27/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.5989 - accuracy: 0.9229 - val_loss: 0.6377 - val_accuracy: 0.9189
# Epoch 28/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.6188 - accuracy: 0.9172 - val_loss: 0.6021 - val_accuracy: 0.9217
# Epoch 29/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.6008 - accuracy: 0.9197 - val_loss: 0.6259 - val_accuracy: 0.9132
# Epoch 30/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.5935 - accuracy: 0.9240 - val_loss: 0.6204 - val_accuracy: 0.9174
# Epoch 31/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.6047 - accuracy: 0.9186 - val_loss: 0.6580 - val_accuracy: 0.9075
# Epoch 32/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.5946 - accuracy: 0.9258 - val_loss: 0.6087 - val_accuracy: 0.9167
# Epoch 33/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.5883 - accuracy: 0.9294 - val_loss: 0.6008 - val_accuracy: 0.9203
# Epoch 34/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.5885 - accuracy: 0.9256 - val_loss: 0.5973 - val_accuracy: 0.9274
# Epoch 35/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.5903 - accuracy: 0.9235 - val_loss: 0.6219 - val_accuracy: 0.9039
# Epoch 36/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.5809 - accuracy: 0.9260 - val_loss: 0.6052 - val_accuracy: 0.9189
# Epoch 37/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.5778 - accuracy: 0.9276 - val_loss: 0.5901 - val_accuracy: 0.9345
# Epoch 38/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.5733 - accuracy: 0.9260 - val_loss: 0.5956 - val_accuracy: 0.9217
# Epoch 39/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.5631 - accuracy: 0.9325 - val_loss: 0.5947 - val_accuracy: 0.9238
# Epoch 40/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.5729 - accuracy: 0.9244 - val_loss: 0.5876 - val_accuracy: 0.9246
# Epoch 41/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.5635 - accuracy: 0.9291 - val_loss: 0.5695 - val_accuracy: 0.9302
# Epoch 42/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.5578 - accuracy: 0.9330 - val_loss: 0.5686 - val_accuracy: 0.9260
# Epoch 43/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.5573 - accuracy: 0.9310 - val_loss: 0.5714 - val_accuracy: 0.9274
# Epoch 44/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.5438 - accuracy: 0.9319 - val_loss: 0.5995 - val_accuracy: 0.9260
# Epoch 45/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.5424 - accuracy: 0.9368 - val_loss: 0.5755 - val_accuracy: 0.9231
# Epoch 46/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.5371 - accuracy: 0.9345 - val_loss: 0.5688 - val_accuracy: 0.9281
# Epoch 47/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.5454 - accuracy: 0.9372 - val_loss: 0.5583 - val_accuracy: 0.9352
# Epoch 48/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.5333 - accuracy: 0.9397 - val_loss: 0.5851 - val_accuracy: 0.9310
# Epoch 49/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.5259 - accuracy: 0.9406 - val_loss: 0.5779 - val_accuracy: 0.9310
# Epoch 50/50
# 87/87 [==============================] - 100s 1s/step - loss: 0.5341 - accuracy: 0.9400 - val_loss: 0.5522 - val_accuracy: 0.9288
# Found 1405 validated image filenames belonging to 4 classes.
# 22/22 [==============================] - 20s 912ms/step - loss: 0.5559 - accuracy: 0.9288
# evaluate accuracy: 92.88%
# 22/22 [==============================] - 20s 897ms/step
# File fold_3_model.h5 berhasil diupload ke folder /gdrive/My Drive/SKRIPSI/Result/Xception_coba3/
# File train_df_fold4.pkl berhasil diupload ke folder /gdrive/My Drive/SKRIPSI/Result/Xception_coba3/
# File val_df_fold4.pkl berhasil diupload ke folder /gdrive/My Drive/SKRIPSI/Result/Xception_coba3/
# Found 5619 validated image filenames belonging to 4 classes.
# Found 1404 validated image filenames belonging to 4 classes.
# Epoch 1/50
# 87/87 [==============================] - 112s 1s/step - loss: 1.2879 - accuracy: 0.6866 - val_loss: 1.2393 - val_accuracy: 0.7685
# Epoch 2/50
# 87/87 [==============================] - 100s 1s/step - loss: 1.0098 - accuracy: 0.7903 - val_loss: 0.9948 - val_accuracy: 0.8405
# Epoch 3/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.9102 - accuracy: 0.8227 - val_loss: 0.8805 - val_accuracy: 0.8433
# Epoch 4/50
# 87/87 [==============================] - 103s 1s/step - loss: 0.8669 - accuracy: 0.8414 - val_loss: 0.8222 - val_accuracy: 0.8462
# Epoch 5/50
# 87/87 [==============================] - 102s 1s/step - loss: 0.8501 - accuracy: 0.8419 - val_loss: 0.7639 - val_accuracy: 0.8732
# Epoch 6/50
# 87/87 [==============================] - 102s 1s/step - loss: 0.8031 - accuracy: 0.8637 - val_loss: 0.7675 - val_accuracy: 0.8697
# Epoch 7/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.7862 - accuracy: 0.8671 - val_loss: 0.7357 - val_accuracy: 0.8889
# Epoch 8/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.7661 - accuracy: 0.8765 - val_loss: 0.7380 - val_accuracy: 0.8768
# Epoch 9/50
# 87/87 [==============================] - 102s 1s/step - loss: 0.7490 - accuracy: 0.8801 - val_loss: 0.7052 - val_accuracy: 0.8953
# Epoch 10/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.7388 - accuracy: 0.8848 - val_loss: 0.7089 - val_accuracy: 0.8889
# Epoch 11/50
# 87/87 [==============================] - 102s 1s/step - loss: 0.7321 - accuracy: 0.8790 - val_loss: 0.7269 - val_accuracy: 0.8818
# Epoch 12/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.7189 - accuracy: 0.8864 - val_loss: 0.6951 - val_accuracy: 0.8953
# Epoch 13/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.7068 - accuracy: 0.8947 - val_loss: 0.7058 - val_accuracy: 0.9003
# Epoch 14/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.6918 - accuracy: 0.8950 - val_loss: 0.6876 - val_accuracy: 0.9003
# Epoch 15/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.7012 - accuracy: 0.8961 - val_loss: 0.6689 - val_accuracy: 0.9024
# Epoch 16/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.6777 - accuracy: 0.9021 - val_loss: 0.6717 - val_accuracy: 0.9053
# Epoch 17/50
# 87/87 [==============================] - 103s 1s/step - loss: 0.6716 - accuracy: 0.9008 - val_loss: 0.6565 - val_accuracy: 0.9145
# Epoch 18/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.6670 - accuracy: 0.9028 - val_loss: 0.6665 - val_accuracy: 0.9138
# Epoch 19/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.6612 - accuracy: 0.9050 - val_loss: 0.6649 - val_accuracy: 0.9160
# Epoch 20/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.6491 - accuracy: 0.9114 - val_loss: 0.6404 - val_accuracy: 0.9160
# Epoch 21/50
# 87/87 [==============================] - 102s 1s/step - loss: 0.6415 - accuracy: 0.9100 - val_loss: 0.6270 - val_accuracy: 0.9188
# Epoch 22/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.6420 - accuracy: 0.9134 - val_loss: 0.6085 - val_accuracy: 0.9238
# Epoch 23/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.6337 - accuracy: 0.9159 - val_loss: 0.6387 - val_accuracy: 0.9188
# Epoch 24/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.6375 - accuracy: 0.9149 - val_loss: 0.6326 - val_accuracy: 0.9167
# Epoch 25/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.6298 - accuracy: 0.9163 - val_loss: 0.6499 - val_accuracy: 0.9095
# Epoch 26/50
# 87/87 [==============================] - 102s 1s/step - loss: 0.6256 - accuracy: 0.9183 - val_loss: 0.6176 - val_accuracy: 0.9209
# Epoch 27/50
# 87/87 [==============================] - 103s 1s/step - loss: 0.6196 - accuracy: 0.9192 - val_loss: 0.6106 - val_accuracy: 0.9202
# Found 1404 validated image filenames belonging to 4 classes.
# 22/22 [==============================] - 21s 947ms/step - loss: 0.6085 - accuracy: 0.9259
# evaluate accuracy: 92.59%
# 22/22 [==============================] - 21s 916ms/step
# File fold_4_model.h5 berhasil diupload ke folder /gdrive/My Drive/SKRIPSI/Result/Xception_coba3/
# File train_df_fold5.pkl berhasil diupload ke folder /gdrive/My Drive/SKRIPSI/Result/Xception_coba3/
# File val_df_fold5.pkl berhasil diupload ke folder /gdrive/My Drive/SKRIPSI/Result/Xception_coba3/
# Found 5619 validated image filenames belonging to 4 classes.
# Found 1404 validated image filenames belonging to 4 classes.
# Epoch 1/50
# 87/87 [==============================] - 107s 1s/step - loss: 1.3176 - accuracy: 0.6664 - val_loss: 1.3869 - val_accuracy: 0.6660
# Epoch 2/50
# 87/87 [==============================] - 103s 1s/step - loss: 1.0017 - accuracy: 0.7824 - val_loss: 1.1448 - val_accuracy: 0.7393
# Epoch 3/50
# 87/87 [==============================] - 102s 1s/step - loss: 0.8967 - accuracy: 0.8180 - val_loss: 0.9229 - val_accuracy: 0.8283
# Epoch 4/50
# 87/87 [==============================] - 103s 1s/step - loss: 0.8684 - accuracy: 0.8364 - val_loss: 0.8477 - val_accuracy: 0.8454
# Epoch 5/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.8340 - accuracy: 0.8423 - val_loss: 0.7859 - val_accuracy: 0.8682
# Epoch 6/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.8098 - accuracy: 0.8569 - val_loss: 0.7588 - val_accuracy: 0.8711
# Epoch 7/50
# 87/87 [==============================] - 102s 1s/step - loss: 0.7764 - accuracy: 0.8682 - val_loss: 0.7516 - val_accuracy: 0.8839
# Epoch 8/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.7685 - accuracy: 0.8648 - val_loss: 0.7087 - val_accuracy: 0.8910
# Epoch 9/50
# 87/87 [==============================] - 102s 1s/step - loss: 0.7518 - accuracy: 0.8747 - val_loss: 0.6957 - val_accuracy: 0.8932
# Epoch 10/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.7385 - accuracy: 0.8781 - val_loss: 0.6937 - val_accuracy: 0.8939
# Epoch 11/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.7229 - accuracy: 0.8882 - val_loss: 0.6931 - val_accuracy: 0.9060
# Epoch 12/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.7192 - accuracy: 0.8877 - val_loss: 0.7057 - val_accuracy: 0.9046
# Epoch 13/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.6984 - accuracy: 0.8911 - val_loss: 0.6847 - val_accuracy: 0.8996
# Epoch 14/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.6992 - accuracy: 0.8889 - val_loss: 0.6658 - val_accuracy: 0.9081
# Epoch 15/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.6906 - accuracy: 0.8954 - val_loss: 0.6709 - val_accuracy: 0.8996
# Epoch 16/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.6738 - accuracy: 0.9039 - val_loss: 0.6412 - val_accuracy: 0.9188
# Epoch 17/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.6637 - accuracy: 0.9096 - val_loss: 0.6758 - val_accuracy: 0.8967
# Epoch 18/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.6689 - accuracy: 0.9035 - val_loss: 0.6479 - val_accuracy: 0.9152
# Epoch 19/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.6428 - accuracy: 0.9122 - val_loss: 0.6506 - val_accuracy: 0.9110
# Epoch 20/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.6385 - accuracy: 0.9136 - val_loss: 0.6472 - val_accuracy: 0.9138
# Epoch 21/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.6525 - accuracy: 0.9096 - val_loss: 0.6410 - val_accuracy: 0.9038
# Epoch 22/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.6457 - accuracy: 0.9082 - val_loss: 0.6442 - val_accuracy: 0.9124
# Epoch 23/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.6380 - accuracy: 0.9131 - val_loss: 0.6476 - val_accuracy: 0.9131
# Epoch 24/50
# 87/87 [==============================] - 102s 1s/step - loss: 0.6369 - accuracy: 0.9098 - val_loss: 0.6278 - val_accuracy: 0.9138
# Epoch 25/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.6243 - accuracy: 0.9176 - val_loss: 0.6090 - val_accuracy: 0.9217
# Epoch 26/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.6102 - accuracy: 0.9221 - val_loss: 0.6229 - val_accuracy: 0.9131
# Epoch 27/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.6152 - accuracy: 0.9215 - val_loss: 0.6364 - val_accuracy: 0.9138
# Epoch 28/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.5965 - accuracy: 0.9244 - val_loss: 0.6287 - val_accuracy: 0.9174
# Epoch 29/50
# 87/87 [==============================] - 101s 1s/step - loss: 0.6027 - accuracy: 0.9212 - val_loss: 0.6205 - val_accuracy: 0.9117
# Epoch 30/50
# 87/87 [==============================] - 102s 1s/step - loss: 0.5917 - accuracy: 0.9276 - val_loss: 0.6453 - val_accuracy: 0.9152
# Found 1404 validated image filenames belonging to 4 classes.
# 22/22 [==============================] - 21s 927ms/step - loss: 0.6386 - accuracy: 0.9103
# evaluate accuracy: 91.03%
# 22/22 [==============================] - 21s 903ms/step
# File fold_5_model.h5 berhasil diupload ke folder /gdrive/My Drive/SKRIPSI/Result/Xception_coba3/
# Best Fold: 3
# Best Sensitivity: 0.9332025790403451

# %%
print('Avarage:')
df_results
# Out:
# Avarage:
#    fold  accuracy  precision  sensitivity  specificity  f1-score  time_taken
# 0     1  0.918861   0.917025     0.915542     0.900000  0.915974   53.105370
# 1     2  0.893950   0.890319     0.888828     0.900641  0.889185   25.863721
# 2     3  0.935943   0.935173     0.933203     0.897516  0.933602   87.108420
# 3     4  0.911681   0.909701     0.907735     0.889590  0.908380   52.598509
# 4     5  0.909544   0.906008     0.905178     0.891026  0.904804   58.895514

# %%
# # Tampilkan label sebelum di encode
# print("Label sebelum di encode: ", set(image_labels))
# # Tampilkan label setelah di encode
# print("Label setelah di encode: ", set(image_labels_encoded))

pd.DataFrame(df_results_class)
print('Class:')
df_results_class
# Out:
# Class:
#     fold       class  accuracy  precision  sensitivity  specificity  f1-score  \
# 0      1      glioma  0.918861   0.941176     0.888889     0.900000  0.914286
# 1      1  meningioma  0.918861   0.836257     0.869301     0.900000  0.852459
# 2      1     notumor  0.918861   0.984848     0.975000     0.900000  0.979899
# 3      1   pituitary  0.918861   0.905817     0.928977     0.900000  0.917251
# 4      2      glioma  0.893950   0.900641     0.867284     0.900641  0.883648
# 5      2  meningioma  0.893950   0.830128     0.787234     0.900641  0.808112
# 6      2     notumor  0.893950   0.937650     0.977500     0.900641  0.957160
# 7      2   pituitary  0.893950   0.892857     0.923295     0.900641  0.907821
# 8      3      glioma  0.935943   0.960133     0.889231     0.897516  0.923323
# 9      3  meningioma  0.935943   0.851852     0.908815     0.897516  0.879412
# 10     3     notumor  0.935943   0.984887     0.977500     0.897516  0.981179
# 11     3   pituitary  0.935943   0.943820     0.957265     0.897516  0.950495
# 12     4      glioma  0.911681   0.930693     0.870370     0.889590  0.899522
# 13     4  meningioma  0.911681   0.826979     0.857143     0.889590  0.841791
# 14     4     notumor  0.911681   0.963054     0.977500     0.889590  0.970223
# 15     4   pituitary  0.911681   0.918079     0.925926     0.889590  0.921986
# 16     5      glioma  0.909544   0.891026     0.858025     0.891026  0.874214
# 17     5  meningioma  0.909544   0.859425     0.817629     0.891026  0.838006
# 18     5     notumor  0.909544   0.984694     0.965000     0.891026  0.974747
# 19     5   pituitary  0.909544   0.888889     0.980057     0.891026  0.932249
#
#     time_taken
# 0    53.105370
# 1    53.105370
# 2    53.105370
# 3    53.105370
# 4    25.863721
# 5    25.863721
# 6    25.863721
# 7    25.863721
# 8    87.108420
# 9    87.108420
# 10   87.108420
# 11   87.108420
# 12   52.598509
# 13   52.598509
# 14   52.598509
# 15   52.598509
# 16   58.895514
# 17   58.895514
# 18   58.895514
# 19   58.895514

# %% [markdown]
# # **Section two:** We will start fine tunning

# %%
model.trainable = True

# Let's take a look to see how many layers are in the base model
print("Number of layers in the base model: ", len(model.layers))

# Fine-tune from this layer onwards
fine_tune_at = 100

# Freeze all the layers before the `fine_tune_at` layer
for layer in model.layers[:fine_tune_at]:
  layer.trainable = False

model.summary()
# Out:
# Number of layers in the base model:  140
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 299, 299, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 149, 149, 32  864         ['input_5[0][0]']
#                                 )
#
#  block1_conv1_bn (BatchNormaliz  (None, 149, 149, 32  128        ['block1_conv1[0][0]']
#  ation)                         )
#
#  block1_conv1_act (Activation)  (None, 149, 149, 32  0           ['block1_conv1_bn[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 147, 147, 64  18432       ['block1_conv1_act[0][0]']
#                                 )
#
#  block1_conv2_bn (BatchNormaliz  (None, 147, 147, 64  256        ['block1_conv2[0][0]']
#  ation)                         )
#
#  block1_conv2_act (Activation)  (None, 147, 147, 64  0           ['block1_conv2_bn[0][0]']
#                                 )
#
#  block2_sepconv1 (SeparableConv  (None, 147, 147, 12  8768       ['block1_conv2_act[0][0]']
#  2D)                            8)
#
#  block2_sepconv1_bn (BatchNorma  (None, 147, 147, 12  512        ['block2_sepconv1[0][0]']
#  lization)                      8)
#
#  block2_sepconv2_act (Activatio  (None, 147, 147, 12  0          ['block2_sepconv1_bn[0][0]']
#  n)                             8)
#
#  block2_sepconv2 (SeparableConv  (None, 147, 147, 12  17536      ['block2_sepconv2_act[0][0]']
#  2D)                            8)
#
#  block2_sepconv2_bn (BatchNorma  (None, 147, 147, 12  512        ['block2_sepconv2[0][0]']
#  lization)                      8)
#
#  conv2d_16 (Conv2D)             (None, 74, 74, 128)  8192        ['block1_conv2_act[0][0]']
#
#  block2_pool (MaxPooling2D)     (None, 74, 74, 128)  0           ['block2_sepconv2_bn[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 74, 74, 128)  512        ['conv2d_16[0][0]']
#  ormalization)
#
#  add_48 (Add)                   (None, 74, 74, 128)  0           ['block2_pool[0][0]',
#                                                                   'batch_normalization_24[0][0]']
#
#  block3_sepconv1_act (Activatio  (None, 74, 74, 128)  0          ['add_48[0][0]']
#  n)
#
#  block3_sepconv1 (SeparableConv  (None, 74, 74, 256)  33920      ['block3_sepconv1_act[0][0]']
#  2D)
#
#  block3_sepconv1_bn (BatchNorma  (None, 74, 74, 256)  1024       ['block3_sepconv1[0][0]']
#  lization)
#
#  block3_sepconv2_act (Activatio  (None, 74, 74, 256)  0          ['block3_sepconv1_bn[0][0]']
#  n)
#
#  block3_sepconv2 (SeparableConv  (None, 74, 74, 256)  67840      ['block3_sepconv2_act[0][0]']
#  2D)
#
#  block3_sepconv2_bn (BatchNorma  (None, 74, 74, 256)  1024       ['block3_sepconv2[0][0]']
#  lization)
#
#  conv2d_17 (Conv2D)             (None, 37, 37, 256)  32768       ['add_48[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 37, 37, 256)  0           ['block3_sepconv2_bn[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 37, 37, 256)  1024       ['conv2d_17[0][0]']
#  ormalization)
#
#  add_49 (Add)                   (None, 37, 37, 256)  0           ['block3_pool[0][0]',
#                                                                   'batch_normalization_25[0][0]']
#
#  block4_sepconv1_act (Activatio  (None, 37, 37, 256)  0          ['add_49[0][0]']
#  n)
#
#  block4_sepconv1 (SeparableConv  (None, 37, 37, 728)  188672     ['block4_sepconv1_act[0][0]']
#  2D)
#
#  block4_sepconv1_bn (BatchNorma  (None, 37, 37, 728)  2912       ['block4_sepconv1[0][0]']
#  lization)
#
#  block4_sepconv2_act (Activatio  (None, 37, 37, 728)  0          ['block4_sepconv1_bn[0][0]']
#  n)
#
#  block4_sepconv2 (SeparableConv  (None, 37, 37, 728)  536536     ['block4_sepconv2_act[0][0]']
#  2D)
#
#  block4_sepconv2_bn (BatchNorma  (None, 37, 37, 728)  2912       ['block4_sepconv2[0][0]']
#  lization)
#
#  conv2d_18 (Conv2D)             (None, 19, 19, 728)  186368      ['add_49[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 19, 19, 728)  0           ['block4_sepconv2_bn[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 19, 19, 728)  2912       ['conv2d_18[0][0]']
#  ormalization)
#
#  add_50 (Add)                   (None, 19, 19, 728)  0           ['block4_pool[0][0]',
#                                                                   'batch_normalization_26[0][0]']
#
#  block5_sepconv1_act (Activatio  (None, 19, 19, 728)  0          ['add_50[0][0]']
#  n)
#
#  block5_sepconv1 (SeparableConv  (None, 19, 19, 728)  536536     ['block5_sepconv1_act[0][0]']
#  2D)
#
#  block5_sepconv1_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block5_sepconv1[0][0]']
#  lization)
#
#  block5_sepconv2_act (Activatio  (None, 19, 19, 728)  0          ['block5_sepconv1_bn[0][0]']
#  n)
#
#  block5_sepconv2 (SeparableConv  (None, 19, 19, 728)  536536     ['block5_sepconv2_act[0][0]']
#  2D)
#
#  block5_sepconv2_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block5_sepconv2[0][0]']
#  lization)
#
#  block5_sepconv3_act (Activatio  (None, 19, 19, 728)  0          ['block5_sepconv2_bn[0][0]']
#  n)
#
#  block5_sepconv3 (SeparableConv  (None, 19, 19, 728)  536536     ['block5_sepconv3_act[0][0]']
#  2D)
#
#  block5_sepconv3_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block5_sepconv3[0][0]']
#  lization)
#
#  add_51 (Add)                   (None, 19, 19, 728)  0           ['block5_sepconv3_bn[0][0]',
#                                                                   'add_50[0][0]']
#
#  block6_sepconv1_act (Activatio  (None, 19, 19, 728)  0          ['add_51[0][0]']
#  n)
#
#  block6_sepconv1 (SeparableConv  (None, 19, 19, 728)  536536     ['block6_sepconv1_act[0][0]']
#  2D)
#
#  block6_sepconv1_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block6_sepconv1[0][0]']
#  lization)
#
#  block6_sepconv2_act (Activatio  (None, 19, 19, 728)  0          ['block6_sepconv1_bn[0][0]']
#  n)
#
#  block6_sepconv2 (SeparableConv  (None, 19, 19, 728)  536536     ['block6_sepconv2_act[0][0]']
#  2D)
#
#  block6_sepconv2_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block6_sepconv2[0][0]']
#  lization)
#
#  block6_sepconv3_act (Activatio  (None, 19, 19, 728)  0          ['block6_sepconv2_bn[0][0]']
#  n)
#
#  block6_sepconv3 (SeparableConv  (None, 19, 19, 728)  536536     ['block6_sepconv3_act[0][0]']
#  2D)
#
#  block6_sepconv3_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block6_sepconv3[0][0]']
#  lization)
#
#  add_52 (Add)                   (None, 19, 19, 728)  0           ['block6_sepconv3_bn[0][0]',
#                                                                   'add_51[0][0]']
#
#  block7_sepconv1_act (Activatio  (None, 19, 19, 728)  0          ['add_52[0][0]']
#  n)
#
#  block7_sepconv1 (SeparableConv  (None, 19, 19, 728)  536536     ['block7_sepconv1_act[0][0]']
#  2D)
#
#  block7_sepconv1_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block7_sepconv1[0][0]']
#  lization)
#
#  block7_sepconv2_act (Activatio  (None, 19, 19, 728)  0          ['block7_sepconv1_bn[0][0]']
#  n)
#
#  block7_sepconv2 (SeparableConv  (None, 19, 19, 728)  536536     ['block7_sepconv2_act[0][0]']
#  2D)
#
#  block7_sepconv2_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block7_sepconv2[0][0]']
#  lization)
#
#  block7_sepconv3_act (Activatio  (None, 19, 19, 728)  0          ['block7_sepconv2_bn[0][0]']
#  n)
#
#  block7_sepconv3 (SeparableConv  (None, 19, 19, 728)  536536     ['block7_sepconv3_act[0][0]']
#  2D)
#
#  block7_sepconv3_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block7_sepconv3[0][0]']
#  lization)
#
#  add_53 (Add)                   (None, 19, 19, 728)  0           ['block7_sepconv3_bn[0][0]',
#                                                                   'add_52[0][0]']
#
#  block8_sepconv1_act (Activatio  (None, 19, 19, 728)  0          ['add_53[0][0]']
#  n)
#
#  block8_sepconv1 (SeparableConv  (None, 19, 19, 728)  536536     ['block8_sepconv1_act[0][0]']
#  2D)
#
#  block8_sepconv1_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block8_sepconv1[0][0]']
#  lization)
#
#  block8_sepconv2_act (Activatio  (None, 19, 19, 728)  0          ['block8_sepconv1_bn[0][0]']
#  n)
#
#  block8_sepconv2 (SeparableConv  (None, 19, 19, 728)  536536     ['block8_sepconv2_act[0][0]']
#  2D)
#
#  block8_sepconv2_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block8_sepconv2[0][0]']
#  lization)
#
#  block8_sepconv3_act (Activatio  (None, 19, 19, 728)  0          ['block8_sepconv2_bn[0][0]']
#  n)
#
#  block8_sepconv3 (SeparableConv  (None, 19, 19, 728)  536536     ['block8_sepconv3_act[0][0]']
#  2D)
#
#  block8_sepconv3_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block8_sepconv3[0][0]']
#  lization)
#
#  add_54 (Add)                   (None, 19, 19, 728)  0           ['block8_sepconv3_bn[0][0]',
#                                                                   'add_53[0][0]']
#
#  block9_sepconv1_act (Activatio  (None, 19, 19, 728)  0          ['add_54[0][0]']
#  n)
#
#  block9_sepconv1 (SeparableConv  (None, 19, 19, 728)  536536     ['block9_sepconv1_act[0][0]']
#  2D)
#
#  block9_sepconv1_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block9_sepconv1[0][0]']
#  lization)
#
#  block9_sepconv2_act (Activatio  (None, 19, 19, 728)  0          ['block9_sepconv1_bn[0][0]']
#  n)
#
#  block9_sepconv2 (SeparableConv  (None, 19, 19, 728)  536536     ['block9_sepconv2_act[0][0]']
#  2D)
#
#  block9_sepconv2_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block9_sepconv2[0][0]']
#  lization)
#
#  block9_sepconv3_act (Activatio  (None, 19, 19, 728)  0          ['block9_sepconv2_bn[0][0]']
#  n)
#
#  block9_sepconv3 (SeparableConv  (None, 19, 19, 728)  536536     ['block9_sepconv3_act[0][0]']
#  2D)
#
#  block9_sepconv3_bn (BatchNorma  (None, 19, 19, 728)  2912       ['block9_sepconv3[0][0]']
#  lization)
#
#  add_55 (Add)                   (None, 19, 19, 728)  0           ['block9_sepconv3_bn[0][0]',
#                                                                   'add_54[0][0]']
#
#  block10_sepconv1_act (Activati  (None, 19, 19, 728)  0          ['add_55[0][0]']
#  on)
#
#  block10_sepconv1 (SeparableCon  (None, 19, 19, 728)  536536     ['block10_sepconv1_act[0][0]']
#  v2D)
#
#  block10_sepconv1_bn (BatchNorm  (None, 19, 19, 728)  2912       ['block10_sepconv1[0][0]']
#  alization)
#
#  block10_sepconv2_act (Activati  (None, 19, 19, 728)  0          ['block10_sepconv1_bn[0][0]']
#  on)
#
#  block10_sepconv2 (SeparableCon  (None, 19, 19, 728)  536536     ['block10_sepconv2_act[0][0]']
#  v2D)
#
#  block10_sepconv2_bn (BatchNorm  (None, 19, 19, 728)  2912       ['block10_sepconv2[0][0]']
#  alization)
#
#  block10_sepconv3_act (Activati  (None, 19, 19, 728)  0          ['block10_sepconv2_bn[0][0]']
#  on)
#
#  block10_sepconv3 (SeparableCon  (None, 19, 19, 728)  536536     ['block10_sepconv3_act[0][0]']
#  v2D)
#
#  block10_sepconv3_bn (BatchNorm  (None, 19, 19, 728)  2912       ['block10_sepconv3[0][0]']
#  alization)
#
#  add_56 (Add)                   (None, 19, 19, 728)  0           ['block10_sepconv3_bn[0][0]',
#                                                                   'add_55[0][0]']
#
#  block11_sepconv1_act (Activati  (None, 19, 19, 728)  0          ['add_56[0][0]']
#  on)
#
#  block11_sepconv1 (SeparableCon  (None, 19, 19, 728)  536536     ['block11_sepconv1_act[0][0]']
#  v2D)
#
#  block11_sepconv1_bn (BatchNorm  (None, 19, 19, 728)  2912       ['block11_sepconv1[0][0]']
#  alization)
#
#  block11_sepconv2_act (Activati  (None, 19, 19, 728)  0          ['block11_sepconv1_bn[0][0]']
#  on)
#
#  block11_sepconv2 (SeparableCon  (None, 19, 19, 728)  536536     ['block11_sepconv2_act[0][0]']
#  v2D)
#
#  block11_sepconv2_bn (BatchNorm  (None, 19, 19, 728)  2912       ['block11_sepconv2[0][0]']
#  alization)
#
#  block11_sepconv3_act (Activati  (None, 19, 19, 728)  0          ['block11_sepconv2_bn[0][0]']
#  on)
#
#  block11_sepconv3 (SeparableCon  (None, 19, 19, 728)  536536     ['block11_sepconv3_act[0][0]']
#  v2D)
#
#  block11_sepconv3_bn (BatchNorm  (None, 19, 19, 728)  2912       ['block11_sepconv3[0][0]']
#  alization)
#
#  add_57 (Add)                   (None, 19, 19, 728)  0           ['block11_sepconv3_bn[0][0]',
#                                                                   'add_56[0][0]']
#
#  block12_sepconv1_act (Activati  (None, 19, 19, 728)  0          ['add_57[0][0]']
#  on)
#
#  block12_sepconv1 (SeparableCon  (None, 19, 19, 728)  536536     ['block12_sepconv1_act[0][0]']
#  v2D)
#
#  block12_sepconv1_bn (BatchNorm  (None, 19, 19, 728)  2912       ['block12_sepconv1[0][0]']
#  alization)
#
#  block12_sepconv2_act (Activati  (None, 19, 19, 728)  0          ['block12_sepconv1_bn[0][0]']
#  on)
#
#  block12_sepconv2 (SeparableCon  (None, 19, 19, 728)  536536     ['block12_sepconv2_act[0][0]']
#  v2D)
#
#  block12_sepconv2_bn (BatchNorm  (None, 19, 19, 728)  2912       ['block12_sepconv2[0][0]']
#  alization)
#
#  block12_sepconv3_act (Activati  (None, 19, 19, 728)  0          ['block12_sepconv2_bn[0][0]']
#  on)
#
#  block12_sepconv3 (SeparableCon  (None, 19, 19, 728)  536536     ['block12_sepconv3_act[0][0]']
#  v2D)
#
#  block12_sepconv3_bn (BatchNorm  (None, 19, 19, 728)  2912       ['block12_sepconv3[0][0]']
#  alization)
#
#  add_58 (Add)                   (None, 19, 19, 728)  0           ['block12_sepconv3_bn[0][0]',
#                                                                   'add_57[0][0]']
#
#  block13_sepconv1_act (Activati  (None, 19, 19, 728)  0          ['add_58[0][0]']
#  on)
#
#  block13_sepconv1 (SeparableCon  (None, 19, 19, 728)  536536     ['block13_sepconv1_act[0][0]']
#  v2D)
#
#  block13_sepconv1_bn (BatchNorm  (None, 19, 19, 728)  2912       ['block13_sepconv1[0][0]']
#  alization)
#
#  block13_sepconv2_act (Activati  (None, 19, 19, 728)  0          ['block13_sepconv1_bn[0][0]']
#  on)
#
#  block13_sepconv2 (SeparableCon  (None, 19, 19, 1024  752024     ['block13_sepconv2_act[0][0]']
#  v2D)                           )
#
#  block13_sepconv2_bn (BatchNorm  (None, 19, 19, 1024  4096       ['block13_sepconv2[0][0]']
#  alization)                     )
#
#  conv2d_19 (Conv2D)             (None, 10, 10, 1024  745472      ['add_58[0][0]']
#                                 )
#
#  block13_pool (MaxPooling2D)    (None, 10, 10, 1024  0           ['block13_sepconv2_bn[0][0]']
#                                 )
#
#  batch_normalization_27 (BatchN  (None, 10, 10, 1024  4096       ['conv2d_19[0][0]']
#  ormalization)                  )
#
#  add_59 (Add)                   (None, 10, 10, 1024  0           ['block13_pool[0][0]',
#                                 )                                 'batch_normalization_27[0][0]']
#
#  block14_sepconv1 (SeparableCon  (None, 10, 10, 1536  1582080    ['add_59[0][0]']
#  v2D)                           )
#
#  block14_sepconv1_bn (BatchNorm  (None, 10, 10, 1536  6144       ['block14_sepconv1[0][0]']
#  alization)                     )
#
#  block14_sepconv1_act (Activati  (None, 10, 10, 1536  0          ['block14_sepconv1_bn[0][0]']
#  on)                            )
#
#  block14_sepconv2 (SeparableCon  (None, 10, 10, 2048  3159552    ['block14_sepconv1_act[0][0]']
#  v2D)                           )
#
#  block14_sepconv2_bn (BatchNorm  (None, 10, 10, 2048  8192       ['block14_sepconv2[0][0]']
#  alization)                     )
#
#  block14_sepconv2_act (Activati  (None, 10, 10, 2048  0          ['block14_sepconv2_bn[0][0]']
#  on)                            )
#
#  global_average_pooling2d_4 (Gl  (None, 2048)        0           ['block14_sepconv2_act[0][0]']
#  obalAveragePooling2D)
#
#  dense_12 (Dense)               (None, 512)          1049088     ['global_average_pooling2d_4[0][0
#                                                                  ]']
#
#  batch_normalization_28 (BatchN  (None, 512)         2048        ['dense_12[0][0]']
#  ormalization)
#
#  dropout_8 (Dropout)            (None, 512)          0           ['batch_normalization_28[0][0]']
#
#  dense_13 (Dense)               (None, 256)          131328      ['dropout_8[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 256)         1024        ['dense_13[0][0]']
#  ormalization)
#
#  dropout_9 (Dropout)            (None, 256)          0           ['batch_normalization_29[0][0]']
#
#  dense_14 (Dense)               (None, 4)            1028        ['dropout_9[0][0]']
#
# ==================================================================================================
# Total params: 22,045,996
# Trainable params: 10,661,324
# Non-trainable params: 11,384,672
# __________________________________________________________________________________________________

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-5) #PASTIKAN MENGGUNAKAN OPTIMIZER TERBAIK
# compile the model
model.compile(optimizer=optimizer,
          loss='categorical_crossentropy',
          metrics=['accuracy'])

# %%
fine_tune_epochs = 10 #GANTI JIKA BUKAN TESTINg
total_epochs =  epochs_initial + fine_tune_epochs

history_fine = model.fit(train_generator_initial,
                         epochs=total_epochs,
                         initial_epoch=history.epoch[-1],
                         validation_data=val_generator_initial,callbacks=[early_stop])
# Out:
# Epoch 30/60
# 88/88 [==============================] - 118s 1s/step - loss: 0.9882 - accuracy: 0.7831 - val_loss: 0.7626 - val_accuracy: 0.8853
# Epoch 31/60
# 88/88 [==============================] - 102s 1s/step - loss: 0.7960 - accuracy: 0.8521 - val_loss: 0.7274 - val_accuracy: 0.8896
# Epoch 32/60
# 88/88 [==============================] - 102s 1s/step - loss: 0.7433 - accuracy: 0.8724 - val_loss: 0.6851 - val_accuracy: 0.9010
# Epoch 33/60
# 88/88 [==============================] - 102s 1s/step - loss: 0.6986 - accuracy: 0.8850 - val_loss: 0.6595 - val_accuracy: 0.9053
# Epoch 34/60
# 88/88 [==============================] - 102s 1s/step - loss: 0.6728 - accuracy: 0.8957 - val_loss: 0.6411 - val_accuracy: 0.9053
# Epoch 35/60
# 88/88 [==============================] - 102s 1s/step - loss: 0.6511 - accuracy: 0.9030 - val_loss: 0.6353 - val_accuracy: 0.9167
# Epoch 36/60
# 88/88 [==============================] - 102s 1s/step - loss: 0.6233 - accuracy: 0.9144 - val_loss: 0.5965 - val_accuracy: 0.9209
# Epoch 37/60
# 88/88 [==============================] - 102s 1s/step - loss: 0.6077 - accuracy: 0.9185 - val_loss: 0.6032 - val_accuracy: 0.9217
# Epoch 38/60
# 88/88 [==============================] - 103s 1s/step - loss: 0.5942 - accuracy: 0.9235 - val_loss: 0.6018 - val_accuracy: 0.9209
# Epoch 39/60
# 88/88 [==============================] - 102s 1s/step - loss: 0.5747 - accuracy: 0.9286 - val_loss: 0.5854 - val_accuracy: 0.9309
# Epoch 40/60
# 88/88 [==============================] - 102s 1s/step - loss: 0.5761 - accuracy: 0.9290 - val_loss: 0.5732 - val_accuracy: 0.9309
# Epoch 41/60
# 88/88 [==============================] - 102s 1s/step - loss: 0.5614 - accuracy: 0.9352 - val_loss: 0.5718 - val_accuracy: 0.9330
# Epoch 42/60
# 88/88 [==============================] - 103s 1s/step - loss: 0.5506 - accuracy: 0.9381 - val_loss: 0.5657 - val_accuracy: 0.9380
# Epoch 43/60
# 88/88 [==============================] - 103s 1s/step - loss: 0.5446 - accuracy: 0.9386 - val_loss: 0.5611 - val_accuracy: 0.9323
# Epoch 44/60
# 88/88 [==============================] - 102s 1s/step - loss: 0.5327 - accuracy: 0.9466 - val_loss: 0.5412 - val_accuracy: 0.9416
# Epoch 45/60
# 88/88 [==============================] - 103s 1s/step - loss: 0.5316 - accuracy: 0.9457 - val_loss: 0.5502 - val_accuracy: 0.9466
# Epoch 46/60
# 88/88 [==============================] - 102s 1s/step - loss: 0.5231 - accuracy: 0.9502 - val_loss: 0.5411 - val_accuracy: 0.9473
# Epoch 47/60
# 88/88 [==============================] - 102s 1s/step - loss: 0.5120 - accuracy: 0.9534 - val_loss: 0.5332 - val_accuracy: 0.9480
# Epoch 48/60
# 88/88 [==============================] - 102s 1s/step - loss: 0.5028 - accuracy: 0.9550 - val_loss: 0.5310 - val_accuracy: 0.9516
# Epoch 49/60
# 88/88 [==============================] - 102s 1s/step - loss: 0.5097 - accuracy: 0.9541 - val_loss: 0.5151 - val_accuracy: 0.9558
# Epoch 50/60
# 88/88 [==============================] - 102s 1s/step - loss: 0.5063 - accuracy: 0.9559 - val_loss: 0.5218 - val_accuracy: 0.9537
# Epoch 51/60
# 88/88 [==============================] - 102s 1s/step - loss: 0.4919 - accuracy: 0.9616 - val_loss: 0.5252 - val_accuracy: 0.9494
# Epoch 52/60
# 88/88 [==============================] - 102s 1s/step - loss: 0.4910 - accuracy: 0.9596 - val_loss: 0.5310 - val_accuracy: 0.9516
# Epoch 53/60
# 88/88 [==============================] - 102s 1s/step - loss: 0.4938 - accuracy: 0.9605 - val_loss: 0.5081 - val_accuracy: 0.9537
# Epoch 54/60
# 88/88 [==============================] - 102s 1s/step - loss: 0.4874 - accuracy: 0.9612 - val_loss: 0.5261 - val_accuracy: 0.9494
# Epoch 55/60
# 88/88 [==============================] - 102s 1s/step - loss: 0.4835 - accuracy: 0.9621 - val_loss: 0.4885 - val_accuracy: 0.9601
# Epoch 56/60
# 88/88 [==============================] - 102s 1s/step - loss: 0.4764 - accuracy: 0.9665 - val_loss: 0.4991 - val_accuracy: 0.9608
# Epoch 57/60
# 88/88 [==============================] - 102s 1s/step - loss: 0.4765 - accuracy: 0.9667 - val_loss: 0.4992 - val_accuracy: 0.9615
# Epoch 58/60
# 88/88 [==============================] - 102s 1s/step - loss: 0.4755 - accuracy: 0.9683 - val_loss: 0.5135 - val_accuracy: 0.9516
# Epoch 59/60
# 88/88 [==============================] - 102s 1s/step - loss: 0.4667 - accuracy: 0.9696 - val_loss: 0.4910 - val_accuracy: 0.9608
# Epoch 60/60
# 88/88 [==============================] - 102s 1s/step - loss: 0.4680 - accuracy: 0.9699 - val_loss: 0.4776 - val_accuracy: 0.9715

# %%
results_fine = []
results_class_fine = []

toc = time.time()

with open(f'val_df_fold{best_fold}.pkl', 'rb') as f:
    val_df_fine = pickle.load(f)

# Evaluasi model pada validasi set
val_generator = datagen.flow_from_dataframe(dataframe=val_df_fine,
                                        x_col='path',
                                        y_col='label',
                                        color_mode='rgb',
                                        batch_size=batchsize_initial,
                                        class_mode="categorical",
                                        shuffle=False)

predictions = model.predict(val_generator)
y_true = val_generator.labels
y_pred = np.argmax(predictions, axis=1)

# hitung confusion matrix dan hasil evaluasi per kelas
cm = confusion_matrix(y_true, y_pred)
class_names = train_generator_initial.class_indices.keys()
report = classification_report(y_true, y_pred, target_names=class_names, output_dict=True)

# hitung specificity 
tn, fp, fn, tp = cm[0][0], cm[0][1], cm[1][0], cm[1][1]
specificity = []
for i in range(len(class_names)):
    spec = tn / (tn + fp)
    specificity.append(spec)

# tampilkan confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title(f'Confusion Matrix After Fine Tune')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred, average='macro')
sensitivity_ava = recall_score(y_true, y_pred, average='macro')
f1 = f1_score(y_true, y_pred, average='macro')
time_taken = toc - tic

# tampilkan hasil evaluasi per kelas
for i, name in enumerate(class_names):
    results_class_fine.append({'class': name,'accuracy': accuracy,'precision': report[name]['precision'],
                              'sensitivity': report[name]['recall'], 'specificity': specificity[i],
                                'f1-score': report[name]['f1-score'], 'time_taken': time_taken/60.0})

results_fine.append({'accuracy': accuracy,
            'precision': precision,
            'sensitivity': sensitivity_ava,
            'specificity': np.mean(specificity),  # menambahkan rata-rata specificity untuk setiap kelas
            'f1-score': f1,
            'time_taken': time_taken/60.0})

acc += history_fine.history['accuracy']
val_acc += history_fine.history['val_accuracy']

loss += history_fine.history['loss']
val_loss += history_fine.history['val_loss']

plt.figure(figsize=(8, 8))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.ylim([0.8, 1])
plt.plot([epochs_initial-1,epochs_initial-1],
          plt.ylim(), label='Start Fine Tuning')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy Xception After Fine Tune')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.ylim([0, 1.0])
plt.plot([epochs_initial-1,epochs_initial-1],
         plt.ylim(), label='Start Fine Tuning')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss Xception After Fine Tune')
plt.xlabel('epoch')
plt.show()

# Konversi list results ke dalam dataframe pandas
df_results_fine = pd.DataFrame(results_fine, columns=['accuracy','precision', 'sensitivity','specificity', 'f1-score', 'time_taken'])
df_results_class_fine = pd.DataFrame(results_class_fine, columns=['class','accuracy', 'precision','sensitivity', 'specificity', 'f1-score', 'time_taken'])
# Tampilkan hasil evaluasi dalam bentuk tabel
pd.DataFrame(df_results_fine)
pd.DataFrame(df_results_class_fine)
print('Avarage:')
df_results_fine
# Out:
# Found 1405 validated image filenames belonging to 4 classes.
# 22/22 [==============================] - 20s 887ms/step
# Avarage:
#    accuracy  precision  sensitivity  specificity  f1-score  time_taken
# 0  0.981495   0.980745     0.980697     0.978261  0.980684  112.738542

# %%
# evaluation on validation data
scores = model.evaluate(val_generator)
print("%s%s: %.2f%%" % ("evaluate ",model.metrics_names[1], scores[1]*100))
# Out:
# 22/22 [==============================] - 21s 919ms/step - loss: 0.4256 - accuracy: 0.9858
# evaluate accuracy: 98.58%

# %%
# # Tampilkan label sebelum di encode
# print("Label sebelum di encode: ", set(image_labels))
# # Tampilkan label setelah di encode
# print("Label setelah di encode: ", set(image_labels_encoded))

pd.DataFrame(df_results_class_fine)
print('Class:')
df_results_class_fine
# Out:
# Class:
#         class  accuracy  precision  sensitivity  specificity  f1-score  \
# 0      glioma  0.981495   0.981308     0.969231     0.978261  0.975232
# 1  meningioma  0.981495   0.969605     0.969605     0.978261  0.969605
# 2     notumor  0.981495   1.000000     0.992500     0.978261  0.996236
# 3   pituitary  0.981495   0.972067     0.991453     0.978261  0.981664
#
#    time_taken
# 0  112.738542
# 1  112.738542
# 2  112.738542
# 3  112.738542

# %%
model.save(f'model_Xception_final.h5')
upload_drive(f'model_Xception_final.h5',RESULT_FOLDER)
# Out:
# File model_Xception_final.h5 berhasil diupload ke folder /gdrive/My Drive/SKRIPSI/Result/Xception_coba3/

# %%
df_results_class
# Out:
#     fold       class  accuracy  precision  sensitivity  specificity  f1-score  \
# 0      1      glioma  0.918861   0.941176     0.888889     0.900000  0.914286
# 1      1  meningioma  0.918861   0.836257     0.869301     0.900000  0.852459
# 2      1     notumor  0.918861   0.984848     0.975000     0.900000  0.979899
# 3      1   pituitary  0.918861   0.905817     0.928977     0.900000  0.917251
# 4      2      glioma  0.893950   0.900641     0.867284     0.900641  0.883648
# 5      2  meningioma  0.893950   0.830128     0.787234     0.900641  0.808112
# 6      2     notumor  0.893950   0.937650     0.977500     0.900641  0.957160
# 7      2   pituitary  0.893950   0.892857     0.923295     0.900641  0.907821
# 8      3      glioma  0.935943   0.960133     0.889231     0.897516  0.923323
# 9      3  meningioma  0.935943   0.851852     0.908815     0.897516  0.879412
# 10     3     notumor  0.935943   0.984887     0.977500     0.897516  0.981179
# 11     3   pituitary  0.935943   0.943820     0.957265     0.897516  0.950495
# 12     4      glioma  0.911681   0.930693     0.870370     0.889590  0.899522
# 13     4  meningioma  0.911681   0.826979     0.857143     0.889590  0.841791
# 14     4     notumor  0.911681   0.963054     0.977500     0.889590  0.970223
# 15     4   pituitary  0.911681   0.918079     0.925926     0.889590  0.921986
# 16     5      glioma  0.909544   0.891026     0.858025     0.891026  0.874214
# 17     5  meningioma  0.909544   0.859425     0.817629     0.891026  0.838006
# 18     5     notumor  0.909544   0.984694     0.965000     0.891026  0.974747
# 19     5   pituitary  0.909544   0.888889     0.980057     0.891026  0.932249
#
#     time_taken
# 0    53.105370
# 1    53.105370
# 2    53.105370
# 3    53.105370
# 4    25.863721
# 5    25.863721
# 6    25.863721
# 7    25.863721
# 8    87.108420
# 9    87.108420
# 10   87.108420
# 11   87.108420
# 12   52.598509
# 13   52.598509
# 14   52.598509
# 15   52.598509
# 16   58.895514
# 17   58.895514
# 18   58.895514
# 19   58.895514

# %%
df_results_class_fine
# Out:
#         class  accuracy  precision  sensitivity  specificity  f1-score  \
# 0      glioma  0.981495   0.981308     0.969231     0.978261  0.975232
# 1  meningioma  0.981495   0.969605     0.969605     0.978261  0.969605
# 2     notumor  0.981495   1.000000     0.992500     0.978261  0.996236
# 3   pituitary  0.981495   0.972067     0.991453     0.978261  0.981664
#
#    time_taken
# 0  112.738542
# 1  112.738542
# 2  112.738542
# 3  112.738542

# %% [markdown]
# # PREDICT

# %%
# Load the trained model
model = tf.keras.models.load_model('model_Xception_final.h5')

# Define the classes
classes = ['glioma', 'meningioma', 'notumor','pituitary']

# Preprocess the input data
def preprocess_input(img):
    # Resize the input image to match the model's input size
    img = cv2.resize(img, (299, 299))
    # Convert the input image to a float32 array and normalize its pixel values
    img = img.astype(np.float32) / 255.0
    # Add an extra dimension to the input to match the model's input shape
    img = np.expand_dims(img, axis=0)
    return img

# Load the input image
# img_path = '/content/dataset-testing-proccess/no_tumor/image(1)_cropped_0.jpg'
img_path = '/content/Brain Tumor Dataset-proccess/glioma/Te-glTr_0000_cropped_0.jpg'
img = cv2.imread(img_path)

# Preprocess the input image
img = preprocess_input(img)

# Predict the class probabilities for the input image
probs = model.predict(img)[0]

# Convert the probabilities to a predicted class label
predicted_class = classes[np.argmax(probs)]

# Print the predicted class label and probabilities for all classes
print('Predicted class:', predicted_class)
print('Class probabilities:', dict(zip(classes, probs)))
# Out:
# 1/1 [==============================] - 1s 714ms/step
# Predicted class: glioma
# Class probabilities: {'glioma': 0.9582383, 'meningioma': 0.01004024, 'notumor': 0.009935379, 'pituitary': 0.02178613}

# %%
import numpy as np
import cv2
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
from google.colab.patches import cv2_imshow

# Load the saved model
model = load_model('model_Xception_final.h5')

# Load the image and preprocess it
# img_path = '/content/dataset-testing-proccess/no_tumor/image(1)_cropped_0.jpg'
img_path = '/content/Brain Tumor Dataset/glioma/Te-glTr_0000.jpg'
img = image.load_img(img_path, target_size=(299, 299))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = x / 255.

# Predict the segmentation mask for the image
pred_mask = model.predict(x)[0]
pred_mask = np.argmax(pred_mask, axis=-1)
pred_mask = np.expand_dims(pred_mask, axis=-1)

# Resize the mask to the original image size
orig_img = cv2.imread(img_path)
mask = cv2.resize(pred_mask, (orig_img.shape[1], orig_img.shape[0]), interpolation=cv2.INTER_NEAREST)
mask = np.squeeze(mask)

# Threshold the mask to get the tumor region
threshold = 0.5
mask = np.where(mask > threshold, 1, 0)

# Find the contours of the tumor region
contours, _ = cv2.findContours(mask.astype(np.uint8), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Draw the contours on the original image
output_img = orig_img.copy()
for cnt in contours:
    cv2.drawContours(output_img, [cnt], 0, (0, 255, 0), 2)

# Display the output image with contours
cv2_imshow(output_img)
cv2.waitKey(0)
# Out:
# 1/1 [==============================] - 1s 700ms/step
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F18BC108220>
# -1
